# %% [markdown]
# # (시도 2) Node Classification with Graph Neural Networks
# >
#
# - toc:true
# - branch: master
# - badges: true
# - comments: false
# - author: 최서연
# - categories: [GNN]

# %% [markdown]
# ### Import

# %%
import os
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# 2022-06-11 22:40:28.692783: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-11 22:40:28.692809: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ## p=0.3

# %% [markdown]
# ### 데이터 구성

# %%
p=0.3

# %%
papers =pd.concat([pd.concat([pd.DataFrame(np.random.choice(2, 1500, p=[p,1-p]).reshape(500,3),columns=['X1','X2','X3']),
           pd.DataFrame(np.random.choice(2, 1500, p=[1-p,p]).reshape(500,3),columns=['X4','X5','X6']),
                             pd.DataFrame(np.array([['Deep learning']*500]).reshape(500,1),columns=['subject'])],axis=1),
            pd.concat([ pd.DataFrame(np.random.choice(2, 1500, p=[1-p,p]).reshape(500,3),columns=['X1','X2','X3']),
              pd.DataFrame(np.random.choice(2, 1500, p=[p,1-p]).reshape(500,3),columns=['X4','X5','X6']),
                      pd.DataFrame(np.array([['Reinforcement learning']*500]).reshape(500,1),columns=['subject'])],axis=1)],axis=0,ignore_index=True).reset_index().rename(columns={'index':'paper_id'})
papers['paper_id'] = papers['paper_id']+1
papers
# Out:
#      paper_id  X1  X2  X3  X4  X5  X6                 subject
# 0           1   1   0   1   0   1   0           Deep learning
# 1           2   1   1   1   0   0   0           Deep learning
# 2           3   1   1   1   0   0   1           Deep learning
# 3           4   1   1   1   0   0   0           Deep learning
# 4           5   1   1   1   1   1   0           Deep learning
# ..        ...  ..  ..  ..  ..  ..  ..                     ...
# 995       996   0   0   0   1   1   1  Reinforcement learning
# 996       997   0   0   1   0   1   0  Reinforcement learning
# 997       998   1   0   0   0   1   1  Reinforcement learning
# 998       999   0   0   0   1   0   1  Reinforcement learning
# 999      1000   0   1   1   0   1   0  Reinforcement learning
#
# [1000 rows x 8 columns]

# %%
# 나머지 1250 행 reinforcement learning 행 500~1000를 target, source에 임의 부여
citations =  pd.concat([pd.DataFrame(np.array([np.random.choice(range(1,501),size=(2000,1)),np.random.choice(range(1,501),size=(2000,1))]).reshape(2000,2)),
                          pd.DataFrame(np.array([np.random.choice(range(501,1001),size=(2000,1)),np.random.choice(range(501,1001),size=(2000,1))]).reshape(2000,2))],ignore_index=True).rename(columns={0:'target',1:'source'})
citations
# Out:
#       target  source
# 0        486     191
# 1        152     299
# 2        485     221
# 3        328      50
# 4         74     357
# ...      ...     ...
# 3995     679     592
# 3996     670     694
# 3997     578     717
# 3998     878     653
# 3999     764     713
#
# [4000 rows x 2 columns]

# %% [markdown]
# ### 그래프 표현

# %%
#collapse
class_values = sorted(papers["subject"].unique())
class_idx = {name: id for id, name in enumerate(class_values)}
paper_idx = {name: idx for idx, name in enumerate(sorted(papers["paper_id"].unique()))}

papers["paper_id"] = papers["paper_id"].apply(lambda name: paper_idx[name])
citations["source"] = citations["source"].apply(lambda name: paper_idx[name])
citations["target"] = citations["target"].apply(lambda name: paper_idx[name])
papers["subject"] = papers["subject"].apply(lambda value: class_idx[value])

# %%
#collapse
plt.figure(figsize=(10, 10))
colors = papers["subject"].tolist()
cora_graph = nx.from_pandas_edgelist(citations.sample(n=800))
subjects = list(papers[papers["paper_id"].isin(list(cora_graph.nodes))]["subject"])
nx.draw_spring(cora_graph, node_size=15, node_color=subjects)

# %% [markdown]
# ### Test vs Train

# %%
#collapse
train_data, test_data = [], []

for _, group_data in papers.groupby("subject"):
    # Select around 50% of the dataset for training.
    random_selection = np.random.rand(len(group_data.index)) <= 0.5
    train_data.append(group_data[random_selection])
    test_data.append(group_data[~random_selection])

train_data = pd.concat(train_data).sample(frac=1)
test_data = pd.concat(test_data).sample(frac=1)

print("Train data shape:", train_data.shape)
print("Test data shape:", test_data.shape)
# Out:
# Train data shape: (489, 8)
# Test data shape: (511, 8)

# %%
#collapse
hidden_units = [32,32]
learning_rate = 0.01
dropout_rate = 0.5
num_epochs = 300
batch_size = 256

# %%
#collapse
def run_experiment(model, x_train, y_train):
    # Compile the model.
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate),
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
    )
    # Create an early stopping callback.
    early_stopping = keras.callbacks.EarlyStopping(
        monitor="val_acc", patience=50, restore_best_weights=True
    )
    # Fit the model.
    history = model.fit(
        x=x_train,
        y=y_train,
        epochs=num_epochs,
        batch_size=batch_size,
        validation_split=0.15,
        callbacks=[early_stopping],
    )

    return history

# %%
#collapse
def display_learning_curves(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    ax1.plot(history.history["loss"])
    ax1.plot(history.history["val_loss"])
    ax1.legend(["train", "test"], loc="upper right")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")

    ax2.plot(history.history["acc"])
    ax2.plot(history.history["val_acc"])
    ax2.legend(["train", "test"], loc="upper right")
    ax2.set_xlabel("Epochs")
    ax2.set_ylabel("Accuracy")
    plt.show()

# %%
#collapse
def create_ffn(hidden_units, dropout_rate, name=None):
    fnn_layers = []

    for units in hidden_units:
        fnn_layers.append(layers.BatchNormalization())
        fnn_layers.append(layers.Dropout(dropout_rate))
        fnn_layers.append(layers.Dense(units, activation=tf.nn.gelu))

    return keras.Sequential(fnn_layers, name=name)

# %%
#collapse
feature_names = set(papers.columns) - {"paper_id", "subject"}
num_features = len(feature_names)
num_classes = len(class_idx)

# Create train and test features as a numpy array.
x_train = train_data[feature_names].to_numpy()
x_test = test_data[feature_names].to_numpy()
# Create train and test targets as a numpy array.
y_train = train_data["subject"]
y_test = test_data["subject"]

# %%
#collapse
def create_baseline_model(hidden_units, num_classes, dropout_rate=0.2):
    inputs = layers.Input(shape=(num_features,), name="input_features")
    x = create_ffn(hidden_units, dropout_rate, name=f"ffn_block1")(inputs)
    for block_idx in range(4):
        # Create an FFN block.
        x1 = create_ffn(hidden_units, dropout_rate, name=f"ffn_block{block_idx + 2}")(x)
        # Add skip connection.
        x = layers.Add(name=f"skip_connection{block_idx + 2}")([x, x1])
    # Compute logits.
    logits = layers.Dense(num_classes, name="logits")(x)
    # Create the model.
    return keras.Model(inputs=inputs, outputs=logits, name="baseline")


baseline_model = create_baseline_model(hidden_units, num_classes, dropout_rate)
baseline_model.summary()
# Out:
# Model: "baseline"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_features (InputLayer)    [(None, 6)]          0           []
#
#  ffn_block1 (Sequential)        (None, 32)           1432        ['input_features[0][0]']
#
#  ffn_block2 (Sequential)        (None, 32)           2368        ['ffn_block1[0][0]']
#
#  skip_connection2 (Add)         (None, 32)           0           ['ffn_block1[0][0]',
#                                                                   'ffn_block2[0][0]']
#
#  ffn_block3 (Sequential)        (None, 32)           2368        ['skip_connection2[0][0]']
#
#  skip_connection3 (Add)         (None, 32)           0           ['skip_connection2[0][0]',
#                                                                   'ffn_block3[0][0]']
#
#  ffn_block4 (Sequential)        (None, 32)           2368        ['skip_connection3[0][0]']
#
#  skip_connection4 (Add)         (None, 32)           0           ['skip_connection3[0][0]',
#                                                                   'ffn_block4[0][0]']
#
#  ffn_block5 (Sequential)        (None, 32)           2368        ['skip_connection4[0][0]']
#
#  skip_connection5 (Add)         (None, 32)           0           ['skip_connection4[0][0]',
#                                                                   'ffn_block5[0][0]']
#
#  logits (Dense)                 (None, 2)            66          ['skip_connection5[0][0]']
#
# ==================================================================================================
# Total params: 10,970
# Trainable params: 10,382
# Non-trainable params: 588
# __________________________________________________________________________________________________

# %%
#collapse_output
history = run_experiment(baseline_model, x_train, y_train)
# Out:
# Epoch 1/300
# 2/2 [==============================] - 2s 280ms/step - loss: 1.7070 - acc: 0.5181 - val_loss: 0.6350 - val_acc: 0.5811
# Epoch 2/300
# 2/2 [==============================] - 0s 40ms/step - loss: 1.0461 - acc: 0.5904 - val_loss: 0.6046 - val_acc: 0.5811
# Epoch 3/300
# 2/2 [==============================] - 0s 42ms/step - loss: 1.1552 - acc: 0.6193 - val_loss: 0.5830 - val_acc: 0.7568
# Epoch 4/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.7859 - acc: 0.6675 - val_loss: 0.5695 - val_acc: 0.7838
# Epoch 5/300
# 2/2 [==============================] - 0s 41ms/step - loss: 0.8641 - acc: 0.6771 - val_loss: 0.5556 - val_acc: 0.7568
# Epoch 6/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.7265 - acc: 0.6602 - val_loss: 0.5442 - val_acc: 0.7568
# Epoch 7/300
# 2/2 [==============================] - 0s 48ms/step - loss: 0.7723 - acc: 0.6771 - val_loss: 0.5382 - val_acc: 0.7568
# Epoch 8/300
# 2/2 [==============================] - 0s 48ms/step - loss: 0.7036 - acc: 0.7157 - val_loss: 0.5329 - val_acc: 0.7973
# Epoch 9/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.7227 - acc: 0.6819 - val_loss: 0.5323 - val_acc: 0.8649
# Epoch 10/300
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6337 - acc: 0.7566 - val_loss: 0.5380 - val_acc: 0.8378
# Epoch 11/300
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6305 - acc: 0.7229 - val_loss: 0.5483 - val_acc: 0.8514
# Epoch 12/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5849 - acc: 0.7277 - val_loss: 0.5560 - val_acc: 0.8514
# Epoch 13/300
# 2/2 [==============================] - 0s 45ms/step - loss: 0.5831 - acc: 0.7518 - val_loss: 0.5562 - val_acc: 0.8514
# Epoch 14/300
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6253 - acc: 0.7108 - val_loss: 0.5537 - val_acc: 0.8378
# Epoch 15/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6032 - acc: 0.7084 - val_loss: 0.5565 - val_acc: 0.8649
# Epoch 16/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6046 - acc: 0.7157 - val_loss: 0.5617 - val_acc: 0.8514
# Epoch 17/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5553 - acc: 0.7446 - val_loss: 0.5668 - val_acc: 0.8514
# Epoch 18/300
# 2/2 [==============================] - 0s 45ms/step - loss: 0.5626 - acc: 0.7205 - val_loss: 0.5734 - val_acc: 0.8514
# Epoch 19/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5589 - acc: 0.7205 - val_loss: 0.5756 - val_acc: 0.8378
# Epoch 20/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.5871 - acc: 0.7060 - val_loss: 0.5733 - val_acc: 0.8378
# Epoch 21/300
# 2/2 [==============================] - 0s 49ms/step - loss: 0.5544 - acc: 0.7325 - val_loss: 0.5667 - val_acc: 0.8378
# Epoch 22/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5316 - acc: 0.7301 - val_loss: 0.5557 - val_acc: 0.8514
# Epoch 23/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5476 - acc: 0.7277 - val_loss: 0.5477 - val_acc: 0.8514
# Epoch 24/300
# 2/2 [==============================] - 0s 39ms/step - loss: 0.5696 - acc: 0.7422 - val_loss: 0.5435 - val_acc: 0.8649
# Epoch 25/300
# 2/2 [==============================] - 0s 41ms/step - loss: 0.4853 - acc: 0.7663 - val_loss: 0.5405 - val_acc: 0.8378
# Epoch 26/300
# 2/2 [==============================] - 0s 47ms/step - loss: 0.5696 - acc: 0.7229 - val_loss: 0.5411 - val_acc: 0.8514
# Epoch 27/300
# 2/2 [==============================] - 0s 47ms/step - loss: 0.5347 - acc: 0.7422 - val_loss: 0.5440 - val_acc: 0.8378
# Epoch 28/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5488 - acc: 0.7349 - val_loss: 0.5475 - val_acc: 0.8378
# Epoch 29/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.5217 - acc: 0.7614 - val_loss: 0.5492 - val_acc: 0.8378
# Epoch 30/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5413 - acc: 0.7590 - val_loss: 0.5499 - val_acc: 0.8378
# Epoch 31/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4792 - acc: 0.7687 - val_loss: 0.5477 - val_acc: 0.8378
# Epoch 32/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5076 - acc: 0.7759 - val_loss: 0.5436 - val_acc: 0.8514
# Epoch 33/300
# 2/2 [==============================] - 0s 46ms/step - loss: 0.5911 - acc: 0.7325 - val_loss: 0.5392 - val_acc: 0.8514
# Epoch 34/300
# 2/2 [==============================] - 0s 46ms/step - loss: 0.5028 - acc: 0.7542 - val_loss: 0.5355 - val_acc: 0.8514
# Epoch 35/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.5657 - acc: 0.7422 - val_loss: 0.5345 - val_acc: 0.8649
# Epoch 36/300
# 2/2 [==============================] - 0s 41ms/step - loss: 0.5377 - acc: 0.7422 - val_loss: 0.5373 - val_acc: 0.8514
# Epoch 37/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.5112 - acc: 0.7687 - val_loss: 0.5385 - val_acc: 0.8514
# Epoch 38/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5031 - acc: 0.7759 - val_loss: 0.5390 - val_acc: 0.8514
# Epoch 39/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5043 - acc: 0.7614 - val_loss: 0.5383 - val_acc: 0.8514
# Epoch 40/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5152 - acc: 0.7518 - val_loss: 0.5380 - val_acc: 0.8378
# Epoch 41/300
# 2/2 [==============================] - 0s 40ms/step - loss: 0.5108 - acc: 0.7542 - val_loss: 0.5365 - val_acc: 0.8378
# Epoch 42/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5332 - acc: 0.7373 - val_loss: 0.5343 - val_acc: 0.8378
# Epoch 43/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.4903 - acc: 0.7711 - val_loss: 0.5312 - val_acc: 0.8378
# Epoch 44/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.4769 - acc: 0.7711 - val_loss: 0.5248 - val_acc: 0.8378
# Epoch 45/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4794 - acc: 0.7711 - val_loss: 0.5179 - val_acc: 0.8514
# Epoch 46/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5248 - acc: 0.7518 - val_loss: 0.5131 - val_acc: 0.8514
# Epoch 47/300
# 2/2 [==============================] - 0s 49ms/step - loss: 0.4586 - acc: 0.7928 - val_loss: 0.5082 - val_acc: 0.8514
# Epoch 48/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.5037 - acc: 0.7735 - val_loss: 0.5034 - val_acc: 0.8514
# Epoch 49/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.4606 - acc: 0.7759 - val_loss: 0.4980 - val_acc: 0.8514
# Epoch 50/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.5048 - acc: 0.7494 - val_loss: 0.4948 - val_acc: 0.8514
# Epoch 51/300
# 2/2 [==============================] - 0s 48ms/step - loss: 0.4387 - acc: 0.7976 - val_loss: 0.4890 - val_acc: 0.8378
# Epoch 52/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.5044 - acc: 0.7470 - val_loss: 0.4856 - val_acc: 0.8378
# Epoch 53/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.4997 - acc: 0.7518 - val_loss: 0.4850 - val_acc: 0.8378
# Epoch 54/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.4939 - acc: 0.7663 - val_loss: 0.4836 - val_acc: 0.8378
# Epoch 55/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.5149 - acc: 0.7614 - val_loss: 0.4851 - val_acc: 0.8378
# Epoch 56/300
# 2/2 [==============================] - 0s 48ms/step - loss: 0.4943 - acc: 0.7614 - val_loss: 0.4898 - val_acc: 0.8514
# Epoch 57/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.4940 - acc: 0.7663 - val_loss: 0.4928 - val_acc: 0.8378
# Epoch 58/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.5212 - acc: 0.7590 - val_loss: 0.4962 - val_acc: 0.8514
# Epoch 59/300
# 2/2 [==============================] - 0s 54ms/step - loss: 0.4942 - acc: 0.8000 - val_loss: 0.4992 - val_acc: 0.8514

# %%
display_learning_curves(history)

# %%
#collapse
_, test_accuracy = baseline_model.evaluate(x=x_test, y=y_test, verbose=0)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 85.13%

# %% [markdown]
# ### baseline 모델 예측

# %%
#collapse
def generate_random_instances(num_instances):
    token_probability = x_train.mean(axis=0)
    instances = []
    for _ in range(num_instances):
        probabilities = np.random.uniform(size=len(token_probability))
        instance = (probabilities <= token_probability).astype(int)
        instances.append(instance)

    return np.array(instances)


def display_class_probabilities(probabilities):
    for instance_idx, probs in enumerate(probabilities):
        print(f"Instance {instance_idx + 1}:")
        for class_idx, prob in enumerate(probs):
            print(f"- {class_values[class_idx]}: {round(prob * 100, 2)}%")

# %%
#collapse
new_instances = generate_random_instances(num_classes)
logits = baseline_model.predict(new_instances)
probabilities = keras.activations.softmax(tf.convert_to_tensor(logits)).numpy()
display_class_probabilities(probabilities)
# Out:
# Instance 1:
# - Deep learning: 63.0%
# - Reinforcement learning: 37.0%
# Instance 2:
# - Deep learning: 37.82%
# - Reinforcement learning: 62.18%

# %%
#collapse
# Create an edges array (sparse adjacency matrix) of shape [2, num_edges].
edges = citations[["source", "target"]].to_numpy().T
# Create an edge weights array of ones.
edge_weights = tf.ones(shape=edges.shape[1])
# Create a node features array of shape [num_nodes, num_features].
node_features = tf.cast(
    papers.sort_values("paper_id")[feature_names].to_numpy(), dtype=tf.dtypes.float32
)
# Create graph info tuple with node_features, edges, and edge_weights.
graph_info = (node_features, edges, edge_weights)

print("Edges shape:", edges.shape)
print("Edge weight shape:", edge_weights.shape)
print("Nodes shape:", node_features.shape)
# Out:
# Edges shape: (2, 4000)
# Edge weight shape: (4000,)
# Nodes shape: (1000, 6)

# %%
#collapse
class GraphConvLayer(layers.Layer):
    def __init__(
        self,
        hidden_units,
        dropout_rate=0.2,
        aggregation_type="mean",
        combination_type="concat",
        normalize=False,
        *args,
        **kwargs,
    ):
        super(GraphConvLayer, self).__init__(*args, **kwargs)

        self.aggregation_type = aggregation_type
        self.combination_type = combination_type
        self.normalize = normalize

        self.ffn_prepare = create_ffn(hidden_units, dropout_rate)
        if self.combination_type == "gated":
            self.update_fn = layers.GRU(
                units=hidden_units,
                activation="tanh",
                recurrent_activation="sigmoid",
                dropout=dropout_rate,
                return_state=True,
                recurrent_dropout=dropout_rate,
            )
        else:
            self.update_fn = create_ffn(hidden_units, dropout_rate)

    def prepare(self, node_repesentations, weights=None):
        # node_repesentations shape is [num_edges, embedding_dim].
        messages = self.ffn_prepare(node_repesentations)
        if weights is not None:
            messages = messages * tf.expand_dims(weights, -1)
        return messages

    def aggregate(self, node_indices, neighbour_messages):
        # node_indices shape is [num_edges].
        # neighbour_messages shape: [num_edges, representation_dim].
        num_nodes = tf.math.reduce_max(node_indices) + 1
        if self.aggregation_type == "sum":
            aggregated_message = tf.math.unsorted_segment_sum(
                neighbour_messages, node_indices, num_segments=num_nodes
            )
        elif self.aggregation_type == "mean":
            aggregated_message = tf.math.unsorted_segment_mean(
                neighbour_messages, node_indices, num_segments=num_nodes
            )
        elif self.aggregation_type == "max":
            aggregated_message = tf.math.unsorted_segment_max(
                neighbour_messages, node_indices, num_segments=num_nodes
            )
        else:
            raise ValueError(f"Invalid aggregation type: {self.aggregation_type}.")

        return aggregated_message

    def update(self, node_repesentations, aggregated_messages):
        # node_repesentations shape is [num_nodes, representation_dim].
        # aggregated_messages shape is [num_nodes, representation_dim].
        if self.combination_type == "gru":
            # Create a sequence of two elements for the GRU layer.
            h = tf.stack([node_repesentations, aggregated_messages], axis=1)
        elif self.combination_type == "concat":
            # Concatenate the node_repesentations and aggregated_messages.
            h = tf.concat([node_repesentations, aggregated_messages], axis=1)
        elif self.combination_type == "add":
            # Add node_repesentations and aggregated_messages.
            h = node_repesentations + aggregated_messages
        else:
            raise ValueError(f"Invalid combination type: {self.combination_type}.")

        # Apply the processing function.
        node_embeddings = self.update_fn(h)
        if self.combination_type == "gru":
            node_embeddings = tf.unstack(node_embeddings, axis=1)[-1]

        if self.normalize:
            node_embeddings = tf.nn.l2_normalize(node_embeddings, axis=-1)
        return node_embeddings

    def call(self, inputs):
        """Process the inputs to produce the node_embeddings.

        inputs: a tuple of three elements: node_repesentations, edges, edge_weights.
        Returns: node_embeddings of shape [num_nodes, representation_dim].
        """

        node_repesentations, edges, edge_weights = inputs
        # Get node_indices (source) and neighbour_indices (target) from edges.
        node_indices, neighbour_indices = edges[0], edges[1]
        # neighbour_repesentations shape is [num_edges, representation_dim].
        neighbour_repesentations = tf.gather(node_repesentations, neighbour_indices)

        # Prepare the messages of the neighbours.
        neighbour_messages = self.prepare(neighbour_repesentations, edge_weights)
        # Aggregate the neighbour messages.
        aggregated_messages = self.aggregate(node_indices, neighbour_messages)
        # Update the node embedding with the neighbour messages.
        return self.update(node_repesentations, aggregated_messages)

# %%
#collapse
class GNNNodeClassifier(tf.keras.Model):
    def __init__(
        self,
        graph_info,
        num_classes,
        hidden_units,
        aggregation_type="sum",
        combination_type="concat",
        dropout_rate=0.2,
        normalize=True,
        *args,
        **kwargs,
    ):
        super(GNNNodeClassifier, self).__init__(*args, **kwargs)

        # Unpack graph_info to three elements: node_features, edges, and edge_weight.
        node_features, edges, edge_weights = graph_info
        self.node_features = node_features
        self.edges = edges
        self.edge_weights = edge_weights
        # Set edge_weights to ones if not provided.
        if self.edge_weights is None:
            self.edge_weights = tf.ones(shape=edges.shape[1])
        # Scale edge_weights to sum to 1.
        self.edge_weights = self.edge_weights / tf.math.reduce_sum(self.edge_weights)

        # Create a process layer.
        self.preprocess = create_ffn(hidden_units, dropout_rate, name="preprocess")
        # Create the first GraphConv layer.
        self.conv1 = GraphConvLayer(
            hidden_units,
            dropout_rate,
            aggregation_type,
            combination_type,
            normalize,
            name="graph_conv1",
        )
        # Create the second GraphConv layer.
        self.conv2 = GraphConvLayer(
            hidden_units,
            dropout_rate,
            aggregation_type,
            combination_type,
            normalize,
            name="graph_conv2",
        )
        # Create a postprocess layer.
        self.postprocess = create_ffn(hidden_units, dropout_rate, name="postprocess")
        # Create a compute logits layer.
        self.compute_logits = layers.Dense(units=num_classes, name="logits")

    def call(self, input_node_indices):
        # Preprocess the node_features to produce node representations.
        x = self.preprocess(self.node_features)
        # Apply the first graph conv layer.
        x1 = self.conv1((x, self.edges, self.edge_weights))
        # Skip connection.
        x = x1 + x
        # Apply the second graph conv layer.
        x2 = self.conv2((x, self.edges, self.edge_weights))
        # Skip connection.
        x = x2 + x
        # Postprocess node embedding.
        x = self.postprocess(x)
        # Fetch node embeddings for the input node_indices.
        node_embeddings = tf.gather(x, input_node_indices)
        # Compute logits
        return self.compute_logits(node_embeddings)

# %%
#collapse
gnn_model = GNNNodeClassifier(
    graph_info=graph_info,
    num_classes=num_classes,
    hidden_units=hidden_units,
    dropout_rate=dropout_rate,
    name="gnn_model",
)

print("GNN output shape:", gnn_model([1, 10, 100]))

gnn_model.summary()
# Out:
# GNN output shape: tf.Tensor(
# [[-0.09488878 -0.03009798]
#  [ 0.00435636  0.00371682]
#  [-0.08979642 -0.03336654]], shape=(3, 2), dtype=float32)
# Model: "gnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  preprocess (Sequential)     (1000, 32)                1432
#
#  graph_conv1 (GraphConvLayer  multiple                 5888
#  )
#
#  graph_conv2 (GraphConvLayer  multiple                 5888
#  )
#
#  postprocess (Sequential)    (1000, 32)                2368
#
#  logits (Dense)              multiple                  66
#
# =================================================================
# Total params: 15,642
# Trainable params: 14,798
# Non-trainable params: 844
# _________________________________________________________________

# %%
#collapse_Output
x_train = train_data.paper_id.to_numpy()
history = run_experiment(gnn_model, x_train, y_train)
# Out:
# Epoch 1/300
# 2/2 [==============================] - 3s 359ms/step - loss: 0.8444 - acc: 0.4699 - val_loss: 0.6925 - val_acc: 0.4189
# Epoch 2/300
# 2/2 [==============================] - 0s 74ms/step - loss: 0.7269 - acc: 0.5759 - val_loss: 0.6847 - val_acc: 0.4189
# Epoch 3/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.6983 - acc: 0.6193 - val_loss: 0.6703 - val_acc: 0.5946
# Epoch 4/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.6826 - acc: 0.6506 - val_loss: 0.6490 - val_acc: 0.7703
# Epoch 5/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.6561 - acc: 0.6699 - val_loss: 0.6229 - val_acc: 0.8378
# Epoch 6/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.6434 - acc: 0.6434 - val_loss: 0.5930 - val_acc: 0.8514
# Epoch 7/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.6317 - acc: 0.6434 - val_loss: 0.5672 - val_acc: 0.8378
# Epoch 8/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.6111 - acc: 0.6795 - val_loss: 0.5477 - val_acc: 0.8649
# Epoch 9/300
# 2/2 [==============================] - 0s 87ms/step - loss: 0.5925 - acc: 0.6747 - val_loss: 0.5262 - val_acc: 0.8378
# Epoch 10/300
# 2/2 [==============================] - 0s 87ms/step - loss: 0.5656 - acc: 0.7012 - val_loss: 0.4998 - val_acc: 0.8378
# Epoch 11/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.6098 - acc: 0.7012 - val_loss: 0.4740 - val_acc: 0.8378
# Epoch 12/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.6169 - acc: 0.7373 - val_loss: 0.4548 - val_acc: 0.8378
# Epoch 13/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.5409 - acc: 0.7301 - val_loss: 0.4382 - val_acc: 0.8378
# Epoch 14/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.5750 - acc: 0.7084 - val_loss: 0.4230 - val_acc: 0.8378
# Epoch 15/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.5593 - acc: 0.7349 - val_loss: 0.4114 - val_acc: 0.8378
# Epoch 16/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.5438 - acc: 0.7422 - val_loss: 0.4052 - val_acc: 0.8378
# Epoch 17/300
# 2/2 [==============================] - 0s 89ms/step - loss: 0.5702 - acc: 0.6988 - val_loss: 0.4037 - val_acc: 0.8378
# Epoch 18/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.5105 - acc: 0.7783 - val_loss: 0.4047 - val_acc: 0.8378
# Epoch 19/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.5157 - acc: 0.7518 - val_loss: 0.4035 - val_acc: 0.8378
# Epoch 20/300
# 2/2 [==============================] - 0s 89ms/step - loss: 0.5431 - acc: 0.7542 - val_loss: 0.3983 - val_acc: 0.8378
# Epoch 21/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.5428 - acc: 0.7325 - val_loss: 0.3978 - val_acc: 0.8378
# Epoch 22/300
# 2/2 [==============================] - 0s 88ms/step - loss: 0.5567 - acc: 0.7566 - val_loss: 0.3996 - val_acc: 0.8378
# Epoch 23/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.5592 - acc: 0.7253 - val_loss: 0.4027 - val_acc: 0.8378
# Epoch 24/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.4961 - acc: 0.7807 - val_loss: 0.4046 - val_acc: 0.8378
# Epoch 25/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.5369 - acc: 0.7253 - val_loss: 0.4039 - val_acc: 0.8514
# Epoch 26/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.5035 - acc: 0.7928 - val_loss: 0.3959 - val_acc: 0.8514
# Epoch 27/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.4996 - acc: 0.7663 - val_loss: 0.3830 - val_acc: 0.8514
# Epoch 28/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.5064 - acc: 0.7759 - val_loss: 0.3751 - val_acc: 0.8514
# Epoch 29/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.4796 - acc: 0.7711 - val_loss: 0.3646 - val_acc: 0.8514
# Epoch 30/300
# 2/2 [==============================] - 0s 87ms/step - loss: 0.4943 - acc: 0.7542 - val_loss: 0.3517 - val_acc: 0.8649
# Epoch 31/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.4347 - acc: 0.8120 - val_loss: 0.3369 - val_acc: 0.8649
# Epoch 32/300
# 2/2 [==============================] - 0s 88ms/step - loss: 0.4580 - acc: 0.7928 - val_loss: 0.3191 - val_acc: 0.8919
# Epoch 33/300
# 2/2 [==============================] - 0s 76ms/step - loss: 0.4751 - acc: 0.7880 - val_loss: 0.3104 - val_acc: 0.8919
# Epoch 34/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.5053 - acc: 0.7904 - val_loss: 0.3163 - val_acc: 0.8649
# Epoch 35/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.3827 - acc: 0.8434 - val_loss: 0.3282 - val_acc: 0.8649
# Epoch 36/300
# 2/2 [==============================] - 0s 88ms/step - loss: 0.4397 - acc: 0.7880 - val_loss: 0.3442 - val_acc: 0.8649
# Epoch 37/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.4090 - acc: 0.8217 - val_loss: 0.3584 - val_acc: 0.8784
# Epoch 38/300
# 2/2 [==============================] - 0s 74ms/step - loss: 0.3553 - acc: 0.8506 - val_loss: 0.3658 - val_acc: 0.8649
# Epoch 39/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.4497 - acc: 0.8193 - val_loss: 0.3915 - val_acc: 0.8243
# Epoch 40/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.3486 - acc: 0.8434 - val_loss: 0.4216 - val_acc: 0.7703
# Epoch 41/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.3649 - acc: 0.8482 - val_loss: 0.4520 - val_acc: 0.7568
# Epoch 42/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.3969 - acc: 0.8361 - val_loss: 0.4750 - val_acc: 0.7568
# Epoch 43/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.3205 - acc: 0.8867 - val_loss: 0.4438 - val_acc: 0.7432
# Epoch 44/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.3454 - acc: 0.8530 - val_loss: 0.3845 - val_acc: 0.8514
# Epoch 45/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.2927 - acc: 0.8819 - val_loss: 0.3720 - val_acc: 0.9865
# Epoch 46/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.2878 - acc: 0.8843 - val_loss: 0.3869 - val_acc: 0.9730
# Epoch 47/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.3001 - acc: 0.8988 - val_loss: 0.3960 - val_acc: 0.9459
# Epoch 48/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.2146 - acc: 0.9157 - val_loss: 0.3668 - val_acc: 0.9730
# Epoch 49/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.1683 - acc: 0.9446 - val_loss: 0.3108 - val_acc: 1.0000
# Epoch 50/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1424 - acc: 0.9494 - val_loss: 0.2657 - val_acc: 0.9595
# Epoch 51/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.2321 - acc: 0.9157 - val_loss: 0.4301 - val_acc: 0.7027
# Epoch 52/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.1707 - acc: 0.9446 - val_loss: 0.2592 - val_acc: 0.9324
# Epoch 53/300
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1270 - acc: 0.9663 - val_loss: 0.2084 - val_acc: 0.9730
# Epoch 54/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1518 - acc: 0.9398 - val_loss: 0.2728 - val_acc: 0.8784
# Epoch 55/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1766 - acc: 0.9470 - val_loss: 0.2598 - val_acc: 0.9324
# Epoch 56/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1589 - acc: 0.9422 - val_loss: 0.2664 - val_acc: 0.9459
# Epoch 57/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1488 - acc: 0.9566 - val_loss: 0.2676 - val_acc: 0.9459
# Epoch 58/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1717 - acc: 0.9470 - val_loss: 0.2659 - val_acc: 0.9730
# Epoch 59/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1587 - acc: 0.9446 - val_loss: 0.2900 - val_acc: 0.9459
# Epoch 60/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1367 - acc: 0.9518 - val_loss: 0.2862 - val_acc: 0.9595
# Epoch 61/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1372 - acc: 0.9542 - val_loss: 0.2683 - val_acc: 0.9730
# Epoch 62/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1069 - acc: 0.9566 - val_loss: 0.2538 - val_acc: 0.9865
# Epoch 63/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1094 - acc: 0.9614 - val_loss: 0.2402 - val_acc: 0.9730
# Epoch 64/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1195 - acc: 0.9590 - val_loss: 0.2390 - val_acc: 0.9595
# Epoch 65/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1668 - acc: 0.9518 - val_loss: 0.2709 - val_acc: 0.9054
# Epoch 66/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.1793 - acc: 0.9446 - val_loss: 0.3229 - val_acc: 0.8649
# Epoch 67/300
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1086 - acc: 0.9614 - val_loss: 0.3275 - val_acc: 0.8378
# Epoch 68/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.1621 - acc: 0.9446 - val_loss: 0.2903 - val_acc: 0.8784
# Epoch 69/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1336 - acc: 0.9614 - val_loss: 0.2531 - val_acc: 0.8919
# Epoch 70/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0975 - acc: 0.9639 - val_loss: 0.2158 - val_acc: 0.9459
# Epoch 71/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0867 - acc: 0.9783 - val_loss: 0.1856 - val_acc: 0.9595
# Epoch 72/300
# 2/2 [==============================] - 0s 96ms/step - loss: 0.1117 - acc: 0.9566 - val_loss: 0.1703 - val_acc: 0.9730
# Epoch 73/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1470 - acc: 0.9446 - val_loss: 0.1654 - val_acc: 0.9730
# Epoch 74/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1331 - acc: 0.9614 - val_loss: 0.1645 - val_acc: 0.9730
# Epoch 75/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.1037 - acc: 0.9639 - val_loss: 0.1660 - val_acc: 0.9730
# Epoch 76/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1111 - acc: 0.9614 - val_loss: 0.1717 - val_acc: 0.9730
# Epoch 77/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.1173 - acc: 0.9566 - val_loss: 0.1767 - val_acc: 0.9865
# Epoch 78/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1076 - acc: 0.9542 - val_loss: 0.1737 - val_acc: 0.9595
# Epoch 79/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0773 - acc: 0.9759 - val_loss: 0.1914 - val_acc: 0.9459
# Epoch 80/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1066 - acc: 0.9639 - val_loss: 0.2327 - val_acc: 0.9189
# Epoch 81/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1098 - acc: 0.9494 - val_loss: 0.2509 - val_acc: 0.8919
# Epoch 82/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.1045 - acc: 0.9687 - val_loss: 0.2432 - val_acc: 0.9189
# Epoch 83/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.1181 - acc: 0.9590 - val_loss: 0.2240 - val_acc: 0.9189
# Epoch 84/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.1265 - acc: 0.9470 - val_loss: 0.2093 - val_acc: 0.9324
# Epoch 85/300
# 2/2 [==============================] - 0s 88ms/step - loss: 0.1201 - acc: 0.9590 - val_loss: 0.2001 - val_acc: 0.9730
# Epoch 86/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.1043 - acc: 0.9614 - val_loss: 0.1921 - val_acc: 0.9865
# Epoch 87/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0856 - acc: 0.9735 - val_loss: 0.1886 - val_acc: 0.9865
# Epoch 88/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0789 - acc: 0.9759 - val_loss: 0.1870 - val_acc: 0.9595
# Epoch 89/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0920 - acc: 0.9663 - val_loss: 0.1771 - val_acc: 0.9865
# Epoch 90/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.1068 - acc: 0.9614 - val_loss: 0.1700 - val_acc: 0.9865
# Epoch 91/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0930 - acc: 0.9687 - val_loss: 0.1656 - val_acc: 1.0000
# Epoch 92/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0681 - acc: 0.9807 - val_loss: 0.1629 - val_acc: 0.9865
# Epoch 93/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0893 - acc: 0.9614 - val_loss: 0.1697 - val_acc: 0.9595
# Epoch 94/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0780 - acc: 0.9783 - val_loss: 0.1773 - val_acc: 0.9324
# Epoch 95/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0905 - acc: 0.9663 - val_loss: 0.2003 - val_acc: 0.9189
# Epoch 96/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0953 - acc: 0.9735 - val_loss: 0.1876 - val_acc: 0.9189
# Epoch 97/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0544 - acc: 0.9807 - val_loss: 0.1679 - val_acc: 0.9324
# Epoch 98/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0760 - acc: 0.9831 - val_loss: 0.1452 - val_acc: 0.9459
# Epoch 99/300
# 2/2 [==============================] - 0s 100ms/step - loss: 0.0840 - acc: 0.9663 - val_loss: 0.1351 - val_acc: 0.9730

# %%
display_learning_curves(history)

# %%
#collapse
x_test = test_data.paper_id.to_numpy()
_, test_accuracy = gnn_model.evaluate(x=x_test, y=y_test, verbose=0)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 94.91%

# %%
#collapse
# First we add the N new_instances as nodes to the graph
# by appending the new_instance to node_features.
num_nodes = node_features.shape[0]
new_node_features = np.concatenate([node_features, new_instances])
# Second we add the M edges (citations) from each new node to a set
# of existing nodes in a particular subject
new_node_indices = [i + num_nodes for i in range(num_classes)]
new_citations = []
for subject_idx, group in papers.groupby("subject"):
    subject_papers = list(group.paper_id)
    # Select random x papers specific subject.
    selected_paper_indices1 = np.random.choice(subject_papers, 5)
    # Select random y papers from any subject (where y < x).
    selected_paper_indices2 = np.random.choice(list(papers.paper_id), 2)
    # Merge the selected paper indices.
    selected_paper_indices = np.concatenate(
        [selected_paper_indices1, selected_paper_indices2], axis=0
    )
    # Create edges between a citing paper idx and the selected cited papers.
    citing_paper_indx = new_node_indices[subject_idx]
    for cited_paper_idx in selected_paper_indices:
        new_citations.append([citing_paper_indx, cited_paper_idx])

new_citations = np.array(new_citations).T
new_edges = np.concatenate([edges, new_citations], axis=1)

# %%
#collapse
print("Original node_features shape:", gnn_model.node_features.shape)
print("Original edges shape:", gnn_model.edges.shape)
gnn_model.node_features = new_node_features
gnn_model.edges = new_edges
gnn_model.edge_weights = tf.ones(shape=new_edges.shape[1])
print("New node_features shape:", gnn_model.node_features.shape)
print("New edges shape:", gnn_model.edges.shape)

logits = gnn_model.predict(tf.convert_to_tensor(new_node_indices))
probabilities = keras.activations.softmax(tf.convert_to_tensor(logits)).numpy()
display_class_probabilities(probabilities)
# Out:
# Original node_features shape: (1000, 6)
# Original edges shape: (2, 4000)
# New node_features shape: (1002, 6)
# New edges shape: (2, 4014)
# Instance 1:
# - Deep learning: 94.95%
# - Reinforcement learning: 5.05%
# Instance 2:
# - Deep learning: 2.64%
# - Reinforcement learning: 97.36%

# %% [markdown]
# ## p=0.2

# %% [markdown]
# ### 데이터 구성

# %%
p=0.2

# %%
papers =pd.concat([pd.concat([pd.DataFrame(np.random.choice(2, 1500, p=[p,1-p]).reshape(500,3),columns=['X1','X2','X3']),
           pd.DataFrame(np.random.choice(2, 1500, p=[1-p,p]).reshape(500,3),columns=['X4','X5','X6']),
                             pd.DataFrame(np.array([['Deep learning']*500]).reshape(500,1),columns=['subject'])],axis=1),
            pd.concat([ pd.DataFrame(np.random.choice(2, 1500, p=[1-p,p]).reshape(500,3),columns=['X1','X2','X3']),
              pd.DataFrame(np.random.choice(2, 1500, p=[p,1-p]).reshape(500,3),columns=['X4','X5','X6']),
                      pd.DataFrame(np.array([['Reinforcement learning']*500]).reshape(500,1),columns=['subject'])],axis=1)],axis=0,ignore_index=True).reset_index().rename(columns={'index':'paper_id'})
papers['paper_id'] = papers['paper_id']+1

# %%
# 나머지 1250 행 reinforcement learning 행 500~1000를 target, source에 임의 부여
citations =  pd.concat([pd.DataFrame(np.array([np.random.choice(range(1,501),size=(2000,1)),np.random.choice(range(1,501),size=(2000,1))]).reshape(2000,2)),
                          pd.DataFrame(np.array([np.random.choice(range(501,1001),size=(2000,1)),np.random.choice(range(501,1001),size=(2000,1))]).reshape(2000,2))],ignore_index=True).rename(columns={0:'target',1:'source'})

# %% [markdown]
# ### 그래프 표현

# %%
#collapse
class_values = sorted(papers["subject"].unique())
class_idx = {name: id for id, name in enumerate(class_values)}
paper_idx = {name: idx for idx, name in enumerate(sorted(papers["paper_id"].unique()))}

papers["paper_id"] = papers["paper_id"].apply(lambda name: paper_idx[name])
citations["source"] = citations["source"].apply(lambda name: paper_idx[name])
citations["target"] = citations["target"].apply(lambda name: paper_idx[name])
papers["subject"] = papers["subject"].apply(lambda value: class_idx[value])

# %%
#collapse
plt.figure(figsize=(10, 10))
colors = papers["subject"].tolist()
cora_graph = nx.from_pandas_edgelist(citations.sample(n=800))
subjects = list(papers[papers["paper_id"].isin(list(cora_graph.nodes))]["subject"])
nx.draw_spring(cora_graph, node_size=15, node_color=subjects)

# %% [markdown]
# ### Test vs Train

# %%
#collapse
train_data, test_data = [], []

for _, group_data in papers.groupby("subject"):
    # Select around 50% of the dataset for training.
    random_selection = np.random.rand(len(group_data.index)) <= 0.5
    train_data.append(group_data[random_selection])
    test_data.append(group_data[~random_selection])

train_data = pd.concat(train_data).sample(frac=1)
test_data = pd.concat(test_data).sample(frac=1)

print("Train data shape:", train_data.shape)
print("Test data shape:", test_data.shape)
# Out:
# Train data shape: (476, 8)
# Test data shape: (524, 8)

# %%
#collapse
hidden_units = [32,32]
learning_rate = 0.01
dropout_rate = 0.5
num_epochs = 300
batch_size = 256

# %%
#collapse
feature_names = set(papers.columns) - {"paper_id", "subject"}
num_features = len(feature_names)
num_classes = len(class_idx)

# Create train and test features as a numpy array.
x_train = train_data[feature_names].to_numpy()
x_test = test_data[feature_names].to_numpy()
# Create train and test targets as a numpy array.
y_train = train_data["subject"]
y_test = test_data["subject"]

# %%
#collapse_output
history = run_experiment(baseline_model, x_train, y_train)
# Out:
# Epoch 1/300
# 2/2 [==============================] - 2s 235ms/step - loss: 0.5121 - acc: 0.7921 - val_loss: 0.4254 - val_acc: 0.8889
# Epoch 2/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5263 - acc: 0.7550 - val_loss: 0.3747 - val_acc: 0.9583
# Epoch 3/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4626 - acc: 0.8342 - val_loss: 0.3721 - val_acc: 0.9583
# Epoch 4/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3931 - acc: 0.8366 - val_loss: 0.3723 - val_acc: 0.9583
# Epoch 5/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4881 - acc: 0.7995 - val_loss: 0.3693 - val_acc: 0.9306
# Epoch 6/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3986 - acc: 0.8243 - val_loss: 0.3514 - val_acc: 0.9444
# Epoch 7/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3743 - acc: 0.8416 - val_loss: 0.3267 - val_acc: 0.9444
# Epoch 8/300
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3902 - acc: 0.8342 - val_loss: 0.3084 - val_acc: 0.9444
# Epoch 9/300
# 2/2 [==============================] - 0s 41ms/step - loss: 0.3968 - acc: 0.8416 - val_loss: 0.3082 - val_acc: 0.9444
# Epoch 10/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.3586 - acc: 0.8490 - val_loss: 0.3067 - val_acc: 0.9444
# Epoch 11/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.3865 - acc: 0.8366 - val_loss: 0.3041 - val_acc: 0.9444
# Epoch 12/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.3654 - acc: 0.8540 - val_loss: 0.2997 - val_acc: 0.9444
# Epoch 13/300
# 2/2 [==============================] - 0s 49ms/step - loss: 0.3352 - acc: 0.8639 - val_loss: 0.2929 - val_acc: 0.9444
# Epoch 14/300
# 2/2 [==============================] - 0s 46ms/step - loss: 0.3785 - acc: 0.8564 - val_loss: 0.2913 - val_acc: 0.9583
# Epoch 15/300
# 2/2 [==============================] - 0s 45ms/step - loss: 0.3483 - acc: 0.8441 - val_loss: 0.2898 - val_acc: 0.9583
# Epoch 16/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.3175 - acc: 0.8663 - val_loss: 0.2868 - val_acc: 0.9583
# Epoch 17/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4126 - acc: 0.8515 - val_loss: 0.2924 - val_acc: 0.9583
# Epoch 18/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3513 - acc: 0.8639 - val_loss: 0.2978 - val_acc: 0.9583
# Epoch 19/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3626 - acc: 0.8465 - val_loss: 0.3028 - val_acc: 0.9583
# Epoch 20/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3350 - acc: 0.8589 - val_loss: 0.3044 - val_acc: 0.9583
# Epoch 21/300
# 2/2 [==============================] - 0s 41ms/step - loss: 0.3728 - acc: 0.8540 - val_loss: 0.3101 - val_acc: 0.9583
# Epoch 22/300
# 2/2 [==============================] - 0s 45ms/step - loss: 0.3037 - acc: 0.8837 - val_loss: 0.3117 - val_acc: 0.9444
# Epoch 23/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.3492 - acc: 0.8391 - val_loss: 0.3044 - val_acc: 0.9444
# Epoch 24/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.3287 - acc: 0.8515 - val_loss: 0.2944 - val_acc: 0.9444
# Epoch 25/300
# 2/2 [==============================] - 0s 47ms/step - loss: 0.3045 - acc: 0.8688 - val_loss: 0.2782 - val_acc: 0.9444
# Epoch 26/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.3280 - acc: 0.8663 - val_loss: 0.2659 - val_acc: 0.9444
# Epoch 27/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3413 - acc: 0.8540 - val_loss: 0.2554 - val_acc: 0.9583
# Epoch 28/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.2987 - acc: 0.8787 - val_loss: 0.2454 - val_acc: 0.9583
# Epoch 29/300
# 2/2 [==============================] - 0s 45ms/step - loss: 0.3787 - acc: 0.8490 - val_loss: 0.2428 - val_acc: 0.9583
# Epoch 30/300
# 2/2 [==============================] - 0s 49ms/step - loss: 0.3245 - acc: 0.8738 - val_loss: 0.2463 - val_acc: 0.9583
# Epoch 31/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.3278 - acc: 0.8540 - val_loss: 0.2494 - val_acc: 0.9583
# Epoch 32/300
# 2/2 [==============================] - 0s 49ms/step - loss: 0.3316 - acc: 0.8663 - val_loss: 0.2564 - val_acc: 0.9583
# Epoch 33/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.3387 - acc: 0.8540 - val_loss: 0.2657 - val_acc: 0.9583
# Epoch 34/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3147 - acc: 0.8837 - val_loss: 0.2711 - val_acc: 0.9583
# Epoch 35/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3085 - acc: 0.8663 - val_loss: 0.2704 - val_acc: 0.9444
# Epoch 36/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3313 - acc: 0.8589 - val_loss: 0.2654 - val_acc: 0.9444
# Epoch 37/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.2971 - acc: 0.8837 - val_loss: 0.2598 - val_acc: 0.9444
# Epoch 38/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3128 - acc: 0.8490 - val_loss: 0.2513 - val_acc: 0.9583
# Epoch 39/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.2864 - acc: 0.8861 - val_loss: 0.2371 - val_acc: 0.9583
# Epoch 40/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.2762 - acc: 0.8861 - val_loss: 0.2207 - val_acc: 0.9583
# Epoch 41/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2947 - acc: 0.8713 - val_loss: 0.2064 - val_acc: 0.9583
# Epoch 42/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.3227 - acc: 0.8713 - val_loss: 0.1996 - val_acc: 0.9583
# Epoch 43/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.3258 - acc: 0.8564 - val_loss: 0.2012 - val_acc: 0.9583
# Epoch 44/300
# 2/2 [==============================] - 0s 45ms/step - loss: 0.3397 - acc: 0.8465 - val_loss: 0.2068 - val_acc: 0.9583
# Epoch 45/300
# 2/2 [==============================] - 0s 45ms/step - loss: 0.2858 - acc: 0.8837 - val_loss: 0.2105 - val_acc: 0.9583
# Epoch 46/300
# 2/2 [==============================] - 0s 45ms/step - loss: 0.2850 - acc: 0.8886 - val_loss: 0.2110 - val_acc: 0.9583
# Epoch 47/300
# 2/2 [==============================] - 0s 45ms/step - loss: 0.3826 - acc: 0.8317 - val_loss: 0.2173 - val_acc: 0.9583
# Epoch 48/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.2909 - acc: 0.8812 - val_loss: 0.2184 - val_acc: 0.9583
# Epoch 49/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.3772 - acc: 0.8391 - val_loss: 0.2246 - val_acc: 0.9583
# Epoch 50/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.2744 - acc: 0.8787 - val_loss: 0.2193 - val_acc: 0.9583
# Epoch 51/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.3137 - acc: 0.8589 - val_loss: 0.2125 - val_acc: 0.9306
# Epoch 52/300
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2851 - acc: 0.8812 - val_loss: 0.2032 - val_acc: 0.9306

# %%
display_learning_curves(history)

# %%
#collapse
_, test_accuracy = baseline_model.evaluate(x=x_test, y=y_test, verbose=0)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 92.94%

# %% [markdown]
# ### baseline 모델 예측

# %%
#collapse
new_instances = generate_random_instances(num_classes)
logits = baseline_model.predict(new_instances)
probabilities = keras.activations.softmax(tf.convert_to_tensor(logits)).numpy()
display_class_probabilities(probabilities)
# Out:
# Instance 1:
# - Deep learning: 70.98%
# - Reinforcement learning: 29.02%
# Instance 2:
# - Deep learning: 79.17%
# - Reinforcement learning: 20.83%

# %%
#collapse
# Create an edges array (sparse adjacency matrix) of shape [2, num_edges].
edges = citations[["source", "target"]].to_numpy().T
# Create an edge weights array of ones.
edge_weights = tf.ones(shape=edges.shape[1])
# Create a node features array of shape [num_nodes, num_features].
node_features = tf.cast(
    papers.sort_values("paper_id")[feature_names].to_numpy(), dtype=tf.dtypes.float32
)
# Create graph info tuple with node_features, edges, and edge_weights.
graph_info = (node_features, edges, edge_weights)

print("Edges shape:", edges.shape)
print("Edge weight shape:", edge_weights.shape)
print("Nodes shape:", node_features.shape)
# Out:
# Edges shape: (2, 4000)
# Edge weight shape: (4000,)
# Nodes shape: (1000, 6)

# %%
#collapse
gnn_model = GNNNodeClassifier(
    graph_info=graph_info,
    num_classes=num_classes,
    hidden_units=hidden_units,
    dropout_rate=dropout_rate,
    name="gnn_model",
)

print("GNN output shape:", gnn_model([1, 10, 100]))

gnn_model.summary()
# Out:
# GNN output shape: tf.Tensor(
# [[ 0.01592829 -0.10377941]
#  [ 0.0159403  -0.10377868]
#  [-0.05428087 -0.06489757]], shape=(3, 2), dtype=float32)
# Model: "gnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  preprocess (Sequential)     (1000, 32)                1432
#
#  graph_conv1 (GraphConvLayer  multiple                 5888
#  )
#
#  graph_conv2 (GraphConvLayer  multiple                 5888
#  )
#
#  postprocess (Sequential)    (1000, 32)                2368
#
#  logits (Dense)              multiple                  66
#
# =================================================================
# Total params: 15,642
# Trainable params: 14,798
# Non-trainable params: 844
# _________________________________________________________________

# %%
#collapse_Output
x_train = train_data.paper_id.to_numpy()
history = run_experiment(gnn_model, x_train, y_train)
# Out:
# Epoch 1/300
# 2/2 [==============================] - 2s 333ms/step - loss: 0.9933 - acc: 0.5272 - val_loss: 0.6592 - val_acc: 0.8611
# Epoch 2/300
# 2/2 [==============================] - 0s 72ms/step - loss: 0.7233 - acc: 0.6040 - val_loss: 0.6375 - val_acc: 0.6111
# Epoch 3/300
# 2/2 [==============================] - 0s 69ms/step - loss: 0.6346 - acc: 0.6064 - val_loss: 0.6155 - val_acc: 0.7778
# Epoch 4/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.6085 - acc: 0.6757 - val_loss: 0.5696 - val_acc: 0.8194
# Epoch 5/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.5609 - acc: 0.7079 - val_loss: 0.5040 - val_acc: 0.8889
# Epoch 6/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.5102 - acc: 0.7475 - val_loss: 0.4258 - val_acc: 0.9444
# Epoch 7/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.4492 - acc: 0.7946 - val_loss: 0.3357 - val_acc: 0.9722
# Epoch 8/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.4093 - acc: 0.8144 - val_loss: 0.2497 - val_acc: 0.9722
# Epoch 9/300
# 2/2 [==============================] - 0s 87ms/step - loss: 0.3733 - acc: 0.8317 - val_loss: 0.1869 - val_acc: 0.9583
# Epoch 10/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.3832 - acc: 0.8342 - val_loss: 0.1527 - val_acc: 0.9583
# Epoch 11/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.4105 - acc: 0.8168 - val_loss: 0.1366 - val_acc: 0.9306
# Epoch 12/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.3831 - acc: 0.8416 - val_loss: 0.1310 - val_acc: 0.9306
# Epoch 13/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.3645 - acc: 0.8391 - val_loss: 0.1304 - val_acc: 0.9306
# Epoch 14/300
# 2/2 [==============================] - 0s 93ms/step - loss: 0.4375 - acc: 0.8168 - val_loss: 0.1313 - val_acc: 0.9306
# Epoch 15/300
# 2/2 [==============================] - 0s 89ms/step - loss: 0.3633 - acc: 0.8465 - val_loss: 0.1318 - val_acc: 0.9306
# Epoch 16/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.3553 - acc: 0.8564 - val_loss: 0.1319 - val_acc: 0.9306
# Epoch 17/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.4171 - acc: 0.8267 - val_loss: 0.1332 - val_acc: 0.9306
# Epoch 18/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.4079 - acc: 0.8366 - val_loss: 0.1345 - val_acc: 0.9306
# Epoch 19/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.3539 - acc: 0.8614 - val_loss: 0.1345 - val_acc: 0.9306
# Epoch 20/300
# 2/2 [==============================] - 0s 76ms/step - loss: 0.3661 - acc: 0.8441 - val_loss: 0.1316 - val_acc: 0.9306
# Epoch 21/300
# 2/2 [==============================] - 0s 73ms/step - loss: 0.3599 - acc: 0.8540 - val_loss: 0.1287 - val_acc: 0.9306
# Epoch 22/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.3727 - acc: 0.8490 - val_loss: 0.1249 - val_acc: 0.9306
# Epoch 23/300
# 2/2 [==============================] - 0s 88ms/step - loss: 0.3884 - acc: 0.8564 - val_loss: 0.1221 - val_acc: 0.9306
# Epoch 24/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.3523 - acc: 0.8614 - val_loss: 0.1193 - val_acc: 0.9306
# Epoch 25/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.3122 - acc: 0.8663 - val_loss: 0.1143 - val_acc: 0.9306
# Epoch 26/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.3069 - acc: 0.8663 - val_loss: 0.1100 - val_acc: 0.9444
# Epoch 27/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.3309 - acc: 0.8738 - val_loss: 0.1074 - val_acc: 0.9583
# Epoch 28/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.2935 - acc: 0.8861 - val_loss: 0.1055 - val_acc: 0.9583
# Epoch 29/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.2788 - acc: 0.8861 - val_loss: 0.1038 - val_acc: 0.9583
# Epoch 30/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.3047 - acc: 0.8861 - val_loss: 0.1016 - val_acc: 0.9583
# Epoch 31/300
# 2/2 [==============================] - 0s 88ms/step - loss: 0.3126 - acc: 0.8812 - val_loss: 0.0982 - val_acc: 0.9583
# Epoch 32/300
# 2/2 [==============================] - 0s 75ms/step - loss: 0.2874 - acc: 0.8936 - val_loss: 0.0963 - val_acc: 0.9583
# Epoch 33/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.2767 - acc: 0.8960 - val_loss: 0.0919 - val_acc: 0.9722
# Epoch 34/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.2309 - acc: 0.9084 - val_loss: 0.0884 - val_acc: 0.9722
# Epoch 35/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.2770 - acc: 0.8762 - val_loss: 0.0858 - val_acc: 0.9722
# Epoch 36/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.2321 - acc: 0.9035 - val_loss: 0.0790 - val_acc: 0.9722
# Epoch 37/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.2216 - acc: 0.9109 - val_loss: 0.0725 - val_acc: 0.9861
# Epoch 38/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.2109 - acc: 0.9233 - val_loss: 0.0659 - val_acc: 0.9861
# Epoch 39/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.2081 - acc: 0.9183 - val_loss: 0.0576 - val_acc: 0.9861
# Epoch 40/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.2094 - acc: 0.9158 - val_loss: 0.0507 - val_acc: 0.9861
# Epoch 41/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.2312 - acc: 0.9282 - val_loss: 0.0433 - val_acc: 0.9861
# Epoch 42/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.1777 - acc: 0.9332 - val_loss: 0.0515 - val_acc: 0.9861
# Epoch 43/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.1453 - acc: 0.9554 - val_loss: 0.0566 - val_acc: 0.9861
# Epoch 44/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1864 - acc: 0.9307 - val_loss: 0.0876 - val_acc: 0.9861
# Epoch 45/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1496 - acc: 0.9530 - val_loss: 0.1114 - val_acc: 0.9861
# Epoch 46/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1475 - acc: 0.9406 - val_loss: 0.1104 - val_acc: 0.9861
# Epoch 47/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1435 - acc: 0.9431 - val_loss: 0.0988 - val_acc: 0.9861
# Epoch 48/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1088 - acc: 0.9579 - val_loss: 0.1050 - val_acc: 0.9861
# Epoch 49/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0795 - acc: 0.9752 - val_loss: 0.1291 - val_acc: 0.9861
# Epoch 50/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.1194 - acc: 0.9554 - val_loss: 0.1378 - val_acc: 0.9583
# Epoch 51/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0842 - acc: 0.9703 - val_loss: 0.1386 - val_acc: 0.9583
# Epoch 52/300
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1094 - acc: 0.9678 - val_loss: 0.1429 - val_acc: 0.9583
# Epoch 53/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1008 - acc: 0.9629 - val_loss: 0.1583 - val_acc: 0.9583
# Epoch 54/300
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1174 - acc: 0.9604 - val_loss: 0.1785 - val_acc: 0.9444
# Epoch 55/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1164 - acc: 0.9653 - val_loss: 0.1775 - val_acc: 0.9444
# Epoch 56/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1137 - acc: 0.9604 - val_loss: 0.1956 - val_acc: 0.9306
# Epoch 57/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0807 - acc: 0.9653 - val_loss: 0.1994 - val_acc: 0.9306
# Epoch 58/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0932 - acc: 0.9752 - val_loss: 0.1836 - val_acc: 0.9306
# Epoch 59/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0808 - acc: 0.9752 - val_loss: 0.1147 - val_acc: 0.9583
# Epoch 60/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0758 - acc: 0.9802 - val_loss: 0.0697 - val_acc: 0.9861
# Epoch 61/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0700 - acc: 0.9777 - val_loss: 0.0444 - val_acc: 0.9861
# Epoch 62/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.0675 - acc: 0.9851 - val_loss: 0.0500 - val_acc: 1.0000
# Epoch 63/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0770 - acc: 0.9802 - val_loss: 0.0474 - val_acc: 1.0000
# Epoch 64/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0674 - acc: 0.9827 - val_loss: 0.0732 - val_acc: 0.9861
# Epoch 65/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0466 - acc: 0.9901 - val_loss: 0.2034 - val_acc: 0.9306
# Epoch 66/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0882 - acc: 0.9752 - val_loss: 0.4409 - val_acc: 0.8472
# Epoch 67/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0735 - acc: 0.9802 - val_loss: 0.5734 - val_acc: 0.8056
# Epoch 68/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0822 - acc: 0.9802 - val_loss: 0.5578 - val_acc: 0.8056
# Epoch 69/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1409 - acc: 0.9629 - val_loss: 0.3996 - val_acc: 0.8333
# Epoch 70/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0704 - acc: 0.9752 - val_loss: 0.1902 - val_acc: 0.9583
# Epoch 71/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0560 - acc: 0.9802 - val_loss: 0.1195 - val_acc: 0.9583
# Epoch 72/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0720 - acc: 0.9678 - val_loss: 0.0899 - val_acc: 0.9861
# Epoch 73/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0966 - acc: 0.9604 - val_loss: 0.0892 - val_acc: 0.9861
# Epoch 74/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0903 - acc: 0.9629 - val_loss: 0.0970 - val_acc: 0.9722
# Epoch 75/300
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0736 - acc: 0.9678 - val_loss: 0.1077 - val_acc: 0.9583
# Epoch 76/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1041 - acc: 0.9703 - val_loss: 0.1213 - val_acc: 0.9583
# Epoch 77/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0561 - acc: 0.9777 - val_loss: 0.1236 - val_acc: 0.9583
# Epoch 78/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0422 - acc: 0.9851 - val_loss: 0.1234 - val_acc: 0.9583
# Epoch 79/300
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0506 - acc: 0.9827 - val_loss: 0.1147 - val_acc: 0.9583
# Epoch 80/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0636 - acc: 0.9827 - val_loss: 0.1185 - val_acc: 0.9583
# Epoch 81/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0955 - acc: 0.9604 - val_loss: 0.1007 - val_acc: 0.9583
# Epoch 82/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0673 - acc: 0.9728 - val_loss: 0.0665 - val_acc: 0.9861
# Epoch 83/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0611 - acc: 0.9802 - val_loss: 0.0485 - val_acc: 0.9861
# Epoch 84/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0450 - acc: 0.9901 - val_loss: 0.0340 - val_acc: 0.9861
# Epoch 85/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0583 - acc: 0.9777 - val_loss: 0.0255 - val_acc: 1.0000
# Epoch 86/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0752 - acc: 0.9802 - val_loss: 0.0241 - val_acc: 1.0000
# Epoch 87/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0484 - acc: 0.9876 - val_loss: 0.0270 - val_acc: 0.9861
# Epoch 88/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0672 - acc: 0.9827 - val_loss: 0.0600 - val_acc: 0.9861
# Epoch 89/300
# 2/2 [==============================] - 0s 76ms/step - loss: 0.0694 - acc: 0.9802 - val_loss: 0.0974 - val_acc: 0.9722
# Epoch 90/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0408 - acc: 0.9876 - val_loss: 0.1076 - val_acc: 0.9583
# Epoch 91/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.0438 - acc: 0.9827 - val_loss: 0.1061 - val_acc: 0.9583
# Epoch 92/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0628 - acc: 0.9777 - val_loss: 0.0722 - val_acc: 0.9722
# Epoch 93/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0759 - acc: 0.9851 - val_loss: 0.0465 - val_acc: 0.9861
# Epoch 94/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0364 - acc: 0.9851 - val_loss: 0.0445 - val_acc: 0.9861
# Epoch 95/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0339 - acc: 0.9901 - val_loss: 0.0450 - val_acc: 0.9861
# Epoch 96/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0485 - acc: 0.9851 - val_loss: 0.0448 - val_acc: 0.9861
# Epoch 97/300
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0392 - acc: 0.9876 - val_loss: 0.0425 - val_acc: 0.9861
# Epoch 98/300
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0488 - acc: 0.9827 - val_loss: 0.0382 - val_acc: 0.9861
# Epoch 99/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0441 - acc: 0.9901 - val_loss: 0.0337 - val_acc: 0.9861
# Epoch 100/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0283 - acc: 0.9876 - val_loss: 0.0358 - val_acc: 0.9861
# Epoch 101/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0402 - acc: 0.9851 - val_loss: 0.0409 - val_acc: 0.9861
# Epoch 102/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0654 - acc: 0.9752 - val_loss: 0.0416 - val_acc: 0.9861
# Epoch 103/300
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0278 - acc: 0.9876 - val_loss: 0.0377 - val_acc: 0.9861
# Epoch 104/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0313 - acc: 0.9876 - val_loss: 0.0363 - val_acc: 0.9861
# Epoch 105/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0543 - acc: 0.9851 - val_loss: 0.0324 - val_acc: 0.9861
# Epoch 106/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0388 - acc: 0.9901 - val_loss: 0.0314 - val_acc: 0.9861
# Epoch 107/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0445 - acc: 0.9876 - val_loss: 0.0305 - val_acc: 0.9861
# Epoch 108/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0491 - acc: 0.9752 - val_loss: 0.0258 - val_acc: 0.9861
# Epoch 109/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0271 - acc: 0.9851 - val_loss: 0.0244 - val_acc: 0.9861
# Epoch 110/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0447 - acc: 0.9901 - val_loss: 0.0258 - val_acc: 0.9861
# Epoch 111/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0405 - acc: 0.9851 - val_loss: 0.0321 - val_acc: 0.9861
# Epoch 112/300
# 2/2 [==============================] - 0s 102ms/step - loss: 0.0286 - acc: 0.9926 - val_loss: 0.0377 - val_acc: 0.9861

# %%
display_learning_curves(history)

# %%
#collapse
x_test = test_data.paper_id.to_numpy()
_, test_accuracy = gnn_model.evaluate(x=x_test, y=y_test, verbose=0)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 97.14%

# %%
#collapse
# First we add the N new_instances as nodes to the graph
# by appending the new_instance to node_features.
num_nodes = node_features.shape[0]
new_node_features = np.concatenate([node_features, new_instances])
# Second we add the M edges (citations) from each new node to a set
# of existing nodes in a particular subject
new_node_indices = [i + num_nodes for i in range(num_classes)]
new_citations = []
for subject_idx, group in papers.groupby("subject"):
    subject_papers = list(group.paper_id)
    # Select random x papers specific subject.
    selected_paper_indices1 = np.random.choice(subject_papers, 5)
    # Select random y papers from any subject (where y < x).
    selected_paper_indices2 = np.random.choice(list(papers.paper_id), 2)
    # Merge the selected paper indices.
    selected_paper_indices = np.concatenate(
        [selected_paper_indices1, selected_paper_indices2], axis=0
    )
    # Create edges between a citing paper idx and the selected cited papers.
    citing_paper_indx = new_node_indices[subject_idx]
    for cited_paper_idx in selected_paper_indices:
        new_citations.append([citing_paper_indx, cited_paper_idx])

new_citations = np.array(new_citations).T
new_edges = np.concatenate([edges, new_citations], axis=1)

# %%
#collapse
print("Original node_features shape:", gnn_model.node_features.shape)
print("Original edges shape:", gnn_model.edges.shape)
gnn_model.node_features = new_node_features
gnn_model.edges = new_edges
gnn_model.edge_weights = tf.ones(shape=new_edges.shape[1])
print("New node_features shape:", gnn_model.node_features.shape)
print("New edges shape:", gnn_model.edges.shape)

logits = gnn_model.predict(tf.convert_to_tensor(new_node_indices))
probabilities = keras.activations.softmax(tf.convert_to_tensor(logits)).numpy()
display_class_probabilities(probabilities)
# Out:
# Original node_features shape: (1000, 6)
# Original edges shape: (2, 4000)
# New node_features shape: (1002, 6)
# New edges shape: (2, 4014)
# Instance 1:
# - Deep learning: 97.43%
# - Reinforcement learning: 2.57%
# Instance 2:
# - Deep learning: 16.74%
# - Reinforcement learning: 83.26%

# %% [markdown]
# ## p=0.4

# %% [markdown]
# ### 데이터 구성

# %%
p=0.2

# %%
papers =pd.concat([pd.concat([pd.DataFrame(np.random.choice(2, 1500, p=[p,1-p]).reshape(500,3),columns=['X1','X2','X3']),
           pd.DataFrame(np.random.choice(2, 1500, p=[1-p,p]).reshape(500,3),columns=['X4','X5','X6']),
                             pd.DataFrame(np.array([['Deep learning']*500]).reshape(500,1),columns=['subject'])],axis=1),
            pd.concat([ pd.DataFrame(np.random.choice(2, 1500, p=[1-p,p]).reshape(500,3),columns=['X1','X2','X3']),
              pd.DataFrame(np.random.choice(2, 1500, p=[p,1-p]).reshape(500,3),columns=['X4','X5','X6']),
                      pd.DataFrame(np.array([['Reinforcement learning']*500]).reshape(500,1),columns=['subject'])],axis=1)],axis=0,ignore_index=True).reset_index().rename(columns={'index':'paper_id'})
papers['paper_id'] = papers['paper_id']+1

# %%
# 나머지 1250 행 reinforcement learning 행 500~1000를 target, source에 임의 부여
citations =  pd.concat([pd.DataFrame(np.array([np.random.choice(range(1,501),size=(2000,1)),np.random.choice(range(1,501),size=(2000,1))]).reshape(2000,2)),
                          pd.DataFrame(np.array([np.random.choice(range(501,1001),size=(2000,1)),np.random.choice(range(501,1001),size=(2000,1))]).reshape(2000,2))],ignore_index=True).rename(columns={0:'target',1:'source'})

# %% [markdown]
# ### 그래프 표현

# %%
#collapse
class_values = sorted(papers["subject"].unique())
class_idx = {name: id for id, name in enumerate(class_values)}
paper_idx = {name: idx for idx, name in enumerate(sorted(papers["paper_id"].unique()))}

papers["paper_id"] = papers["paper_id"].apply(lambda name: paper_idx[name])
citations["source"] = citations["source"].apply(lambda name: paper_idx[name])
citations["target"] = citations["target"].apply(lambda name: paper_idx[name])
papers["subject"] = papers["subject"].apply(lambda value: class_idx[value])

# %%
#collapse
plt.figure(figsize=(10, 10))
colors = papers["subject"].tolist()
cora_graph = nx.from_pandas_edgelist(citations.sample(n=800))
subjects = list(papers[papers["paper_id"].isin(list(cora_graph.nodes))]["subject"])
nx.draw_spring(cora_graph, node_size=15, node_color=subjects)

# %% [markdown]
# ### Test vs Train

# %%
#collapse
train_data, test_data = [], []

for _, group_data in papers.groupby("subject"):
    # Select around 50% of the dataset for training.
    random_selection = np.random.rand(len(group_data.index)) <= 0.5
    train_data.append(group_data[random_selection])
    test_data.append(group_data[~random_selection])

train_data = pd.concat(train_data).sample(frac=1)
test_data = pd.concat(test_data).sample(frac=1)

print("Train data shape:", train_data.shape)
print("Test data shape:", test_data.shape)
# Out:
# Train data shape: (516, 8)
# Test data shape: (484, 8)

# %%
#collapse
hidden_units = [32,32]
learning_rate = 0.01
dropout_rate = 0.5
num_epochs = 300
batch_size = 256

# %%
#collapse
feature_names = set(papers.columns) - {"paper_id", "subject"}
num_features = len(feature_names)
num_classes = len(class_idx)

# Create train and test features as a numpy array.
x_train = train_data[feature_names].to_numpy()
x_test = test_data[feature_names].to_numpy()
# Create train and test targets as a numpy array.
y_train = train_data["subject"]
y_test = test_data["subject"]

# %%
#collapse_output
history = run_experiment(baseline_model, x_train, y_train)
# Out:
# Epoch 1/300
# 2/2 [==============================] - 2s 239ms/step - loss: 0.4414 - acc: 0.8059 - val_loss: 0.3708 - val_acc: 0.9487
# Epoch 2/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3632 - acc: 0.8584 - val_loss: 0.3544 - val_acc: 0.9359
# Epoch 3/300
# 2/2 [==============================] - 0s 40ms/step - loss: 0.4152 - acc: 0.8607 - val_loss: 0.3544 - val_acc: 0.9359
# Epoch 4/300
# 2/2 [==============================] - 0s 41ms/step - loss: 0.3324 - acc: 0.8493 - val_loss: 0.3429 - val_acc: 0.9487
# Epoch 5/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.3498 - acc: 0.8470 - val_loss: 0.3372 - val_acc: 0.9487
# Epoch 6/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.3608 - acc: 0.8584 - val_loss: 0.3229 - val_acc: 0.9487
# Epoch 7/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.3606 - acc: 0.8402 - val_loss: 0.3079 - val_acc: 0.9359
# Epoch 8/300
# 2/2 [==============================] - 0s 45ms/step - loss: 0.3772 - acc: 0.8653 - val_loss: 0.3068 - val_acc: 0.9359
# Epoch 9/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.3544 - acc: 0.8607 - val_loss: 0.3136 - val_acc: 0.9359
# Epoch 10/300
# 2/2 [==============================] - 0s 47ms/step - loss: 0.2823 - acc: 0.8836 - val_loss: 0.3184 - val_acc: 0.9359
# Epoch 11/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.3090 - acc: 0.8767 - val_loss: 0.3200 - val_acc: 0.9359
# Epoch 12/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.3156 - acc: 0.8744 - val_loss: 0.3099 - val_acc: 0.9359
# Epoch 13/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.3308 - acc: 0.8699 - val_loss: 0.3035 - val_acc: 0.9359
# Epoch 14/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.2885 - acc: 0.8607 - val_loss: 0.2993 - val_acc: 0.9359
# Epoch 15/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.3168 - acc: 0.8539 - val_loss: 0.2924 - val_acc: 0.9359
# Epoch 16/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.3136 - acc: 0.8813 - val_loss: 0.2864 - val_acc: 0.9359
# Epoch 17/300
# 2/2 [==============================] - 0s 46ms/step - loss: 0.3176 - acc: 0.8836 - val_loss: 0.2876 - val_acc: 0.9615
# Epoch 18/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3697 - acc: 0.8425 - val_loss: 0.2982 - val_acc: 0.9487
# Epoch 19/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2676 - acc: 0.9018 - val_loss: 0.3021 - val_acc: 0.9487
# Epoch 20/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3805 - acc: 0.8447 - val_loss: 0.3065 - val_acc: 0.9487
# Epoch 21/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3094 - acc: 0.8539 - val_loss: 0.3091 - val_acc: 0.9487
# Epoch 22/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.2886 - acc: 0.8836 - val_loss: 0.3076 - val_acc: 0.9359
# Epoch 23/300
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2866 - acc: 0.8676 - val_loss: 0.3021 - val_acc: 0.9359
# Epoch 24/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3336 - acc: 0.8562 - val_loss: 0.2965 - val_acc: 0.9359
# Epoch 25/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3310 - acc: 0.8493 - val_loss: 0.2967 - val_acc: 0.9487
# Epoch 26/300
# 2/2 [==============================] - 0s 40ms/step - loss: 0.3160 - acc: 0.8699 - val_loss: 0.2953 - val_acc: 0.9487
# Epoch 27/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.3346 - acc: 0.8493 - val_loss: 0.2990 - val_acc: 0.9231
# Epoch 28/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.2870 - acc: 0.8836 - val_loss: 0.2974 - val_acc: 0.9359
# Epoch 29/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.3218 - acc: 0.8584 - val_loss: 0.2915 - val_acc: 0.9359
# Epoch 30/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3450 - acc: 0.8470 - val_loss: 0.2923 - val_acc: 0.9487
# Epoch 31/300
# 2/2 [==============================] - 0s 41ms/step - loss: 0.2719 - acc: 0.8927 - val_loss: 0.2875 - val_acc: 0.9359
# Epoch 32/300
# 2/2 [==============================] - 0s 46ms/step - loss: 0.3497 - acc: 0.8470 - val_loss: 0.2825 - val_acc: 0.9359
# Epoch 33/300
# 2/2 [==============================] - 0s 50ms/step - loss: 0.3114 - acc: 0.8699 - val_loss: 0.2750 - val_acc: 0.9359
# Epoch 34/300
# 2/2 [==============================] - 0s 45ms/step - loss: 0.3041 - acc: 0.8676 - val_loss: 0.2672 - val_acc: 0.9487
# Epoch 35/300
# 2/2 [==============================] - 0s 39ms/step - loss: 0.3019 - acc: 0.8744 - val_loss: 0.2625 - val_acc: 0.9487
# Epoch 36/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3484 - acc: 0.8516 - val_loss: 0.2664 - val_acc: 0.9487
# Epoch 37/300
# 2/2 [==============================] - 0s 50ms/step - loss: 0.3215 - acc: 0.8470 - val_loss: 0.2707 - val_acc: 0.9359
# Epoch 38/300
# 2/2 [==============================] - 0s 48ms/step - loss: 0.3042 - acc: 0.8721 - val_loss: 0.2747 - val_acc: 0.9359
# Epoch 39/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.3204 - acc: 0.8676 - val_loss: 0.2716 - val_acc: 0.9359
# Epoch 40/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.3138 - acc: 0.8767 - val_loss: 0.2685 - val_acc: 0.9359
# Epoch 41/300
# 2/2 [==============================] - 0s 49ms/step - loss: 0.3244 - acc: 0.8516 - val_loss: 0.2678 - val_acc: 0.9359
# Epoch 42/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.2804 - acc: 0.8858 - val_loss: 0.2585 - val_acc: 0.9359
# Epoch 43/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.2955 - acc: 0.8721 - val_loss: 0.2509 - val_acc: 0.9359
# Epoch 44/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.2907 - acc: 0.8721 - val_loss: 0.2359 - val_acc: 0.9359
# Epoch 45/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.2727 - acc: 0.8836 - val_loss: 0.2158 - val_acc: 0.9359
# Epoch 46/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2461 - acc: 0.8881 - val_loss: 0.1995 - val_acc: 0.9487
# Epoch 47/300
# 2/2 [==============================] - 0s 46ms/step - loss: 0.3402 - acc: 0.8607 - val_loss: 0.1924 - val_acc: 0.9487
# Epoch 48/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.2520 - acc: 0.8904 - val_loss: 0.1906 - val_acc: 0.9615
# Epoch 49/300
# 2/2 [==============================] - 0s 49ms/step - loss: 0.2806 - acc: 0.8813 - val_loss: 0.1933 - val_acc: 0.9615
# Epoch 50/300
# 2/2 [==============================] - 0s 48ms/step - loss: 0.2157 - acc: 0.9178 - val_loss: 0.1964 - val_acc: 0.9615
# Epoch 51/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.2855 - acc: 0.8973 - val_loss: 0.1999 - val_acc: 0.9615
# Epoch 52/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.3114 - acc: 0.8653 - val_loss: 0.2084 - val_acc: 0.9615
# Epoch 53/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.3230 - acc: 0.8630 - val_loss: 0.2209 - val_acc: 0.9487
# Epoch 54/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.3022 - acc: 0.8790 - val_loss: 0.2318 - val_acc: 0.9487
# Epoch 55/300
# 2/2 [==============================] - 0s 48ms/step - loss: 0.2795 - acc: 0.8699 - val_loss: 0.2396 - val_acc: 0.9487
# Epoch 56/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.3210 - acc: 0.8311 - val_loss: 0.2439 - val_acc: 0.9359
# Epoch 57/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.2732 - acc: 0.8927 - val_loss: 0.2383 - val_acc: 0.9359
# Epoch 58/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.2877 - acc: 0.8676 - val_loss: 0.2293 - val_acc: 0.9359
# Epoch 59/300
# 2/2 [==============================] - 0s 45ms/step - loss: 0.2673 - acc: 0.8836 - val_loss: 0.2140 - val_acc: 0.9359
# Epoch 60/300
# 2/2 [==============================] - 0s 40ms/step - loss: 0.3002 - acc: 0.8539 - val_loss: 0.2024 - val_acc: 0.9359
# Epoch 61/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3298 - acc: 0.8676 - val_loss: 0.1986 - val_acc: 0.9359
# Epoch 62/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.2617 - acc: 0.8790 - val_loss: 0.1967 - val_acc: 0.9359
# Epoch 63/300
# 2/2 [==============================] - 0s 39ms/step - loss: 0.2555 - acc: 0.8767 - val_loss: 0.1909 - val_acc: 0.9359
# Epoch 64/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.2814 - acc: 0.8836 - val_loss: 0.1863 - val_acc: 0.9359
# Epoch 65/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.2898 - acc: 0.8858 - val_loss: 0.1848 - val_acc: 0.9359
# Epoch 66/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.2627 - acc: 0.8744 - val_loss: 0.1828 - val_acc: 0.9359
# Epoch 67/300
# 2/2 [==============================] - 0s 40ms/step - loss: 0.3131 - acc: 0.8858 - val_loss: 0.1878 - val_acc: 0.9359

# %%
display_learning_curves(history)

# %%
#collapse
_, test_accuracy = baseline_model.evaluate(x=x_test, y=y_test, verbose=0)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 95.04%

# %% [markdown]
# ### baseline 모델 예측

# %%
#collapse
new_instances = generate_random_instances(num_classes)
logits = baseline_model.predict(new_instances)
probabilities = keras.activations.softmax(tf.convert_to_tensor(logits)).numpy()
display_class_probabilities(probabilities)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f83bc5e3c10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Instance 1:
# - Deep learning: 32.21%
# - Reinforcement learning: 67.79%
# Instance 2:
# - Deep learning: 65.48%
# - Reinforcement learning: 34.52%

# %%
#collapse
# Create an edges array (sparse adjacency matrix) of shape [2, num_edges].
edges = citations[["source", "target"]].to_numpy().T
# Create an edge weights array of ones.
edge_weights = tf.ones(shape=edges.shape[1])
# Create a node features array of shape [num_nodes, num_features].
node_features = tf.cast(
    papers.sort_values("paper_id")[feature_names].to_numpy(), dtype=tf.dtypes.float32
)
# Create graph info tuple with node_features, edges, and edge_weights.
graph_info = (node_features, edges, edge_weights)

print("Edges shape:", edges.shape)
print("Edge weight shape:", edge_weights.shape)
print("Nodes shape:", node_features.shape)
# Out:
# Edges shape: (2, 4000)
# Edge weight shape: (4000,)
# Nodes shape: (1000, 6)

# %%
#collapse
gnn_model = GNNNodeClassifier(
    graph_info=graph_info,
    num_classes=num_classes,
    hidden_units=hidden_units,
    dropout_rate=dropout_rate,
    name="gnn_model",
)

print("GNN output shape:", gnn_model([1, 10, 100]))

gnn_model.summary()
# Out:
# GNN output shape: tf.Tensor(
# [[0.08577471 0.00197855]
#  [0.05664444 0.02031855]
#  [0.1098433  0.00504654]], shape=(3, 2), dtype=float32)
# Model: "gnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  preprocess (Sequential)     (1000, 32)                1432
#
#  graph_conv1 (GraphConvLayer  multiple                 5888
#  )
#
#  graph_conv2 (GraphConvLayer  multiple                 5888
#  )
#
#  postprocess (Sequential)    (1000, 32)                2368
#
#  logits (Dense)              multiple                  66
#
# =================================================================
# Total params: 15,642
# Trainable params: 14,798
# Non-trainable params: 844
# _________________________________________________________________

# %%
#collapse_Output
x_train = train_data.paper_id.to_numpy()
history = run_experiment(gnn_model, x_train, y_train)
# Out:
# Epoch 1/300
# 2/2 [==============================] - 2s 359ms/step - loss: 0.8128 - acc: 0.5251 - val_loss: 0.6743 - val_acc: 0.5256
# Epoch 2/300
# 2/2 [==============================] - 0s 72ms/step - loss: 0.7232 - acc: 0.5890 - val_loss: 0.6656 - val_acc: 0.5256
# Epoch 3/300
# 2/2 [==============================] - 0s 70ms/step - loss: 0.6637 - acc: 0.6575 - val_loss: 0.6347 - val_acc: 0.5256
# Epoch 4/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.5610 - acc: 0.6986 - val_loss: 0.5908 - val_acc: 0.7692
# Epoch 5/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.5507 - acc: 0.7032 - val_loss: 0.5305 - val_acc: 0.8462
# Epoch 6/300
# 2/2 [==============================] - 0s 87ms/step - loss: 0.5157 - acc: 0.7580 - val_loss: 0.4488 - val_acc: 0.9359
# Epoch 7/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.5057 - acc: 0.7831 - val_loss: 0.3735 - val_acc: 0.8846
# Epoch 8/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.4313 - acc: 0.8151 - val_loss: 0.3147 - val_acc: 0.8846
# Epoch 9/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.3854 - acc: 0.8402 - val_loss: 0.2808 - val_acc: 0.8846
# Epoch 10/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.3523 - acc: 0.8402 - val_loss: 0.2675 - val_acc: 0.8846
# Epoch 11/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.4874 - acc: 0.8014 - val_loss: 0.2567 - val_acc: 0.8846
# Epoch 12/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.4078 - acc: 0.8402 - val_loss: 0.2509 - val_acc: 0.8846
# Epoch 13/300
# 2/2 [==============================] - 0s 88ms/step - loss: 0.4036 - acc: 0.8493 - val_loss: 0.2497 - val_acc: 0.8846
# Epoch 14/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.4215 - acc: 0.8288 - val_loss: 0.2505 - val_acc: 0.8846
# Epoch 15/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.4019 - acc: 0.8311 - val_loss: 0.2475 - val_acc: 0.8718
# Epoch 16/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.3467 - acc: 0.8927 - val_loss: 0.2306 - val_acc: 0.8846
# Epoch 17/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.3508 - acc: 0.8539 - val_loss: 0.2145 - val_acc: 0.8846
# Epoch 18/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.3413 - acc: 0.8562 - val_loss: 0.1965 - val_acc: 0.9103
# Epoch 19/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.3668 - acc: 0.8607 - val_loss: 0.1866 - val_acc: 0.9103
# Epoch 20/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.3454 - acc: 0.8607 - val_loss: 0.1775 - val_acc: 0.8974
# Epoch 21/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.3853 - acc: 0.8219 - val_loss: 0.1701 - val_acc: 0.9359
# Epoch 22/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.3484 - acc: 0.8653 - val_loss: 0.1637 - val_acc: 0.9359
# Epoch 23/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.3305 - acc: 0.8562 - val_loss: 0.1612 - val_acc: 0.9359
# Epoch 24/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.3456 - acc: 0.8744 - val_loss: 0.1557 - val_acc: 0.9359
# Epoch 25/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.3863 - acc: 0.8333 - val_loss: 0.1513 - val_acc: 0.9359
# Epoch 26/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.3078 - acc: 0.8881 - val_loss: 0.1454 - val_acc: 0.9359
# Epoch 27/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.2843 - acc: 0.8927 - val_loss: 0.1396 - val_acc: 0.9359
# Epoch 28/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.2689 - acc: 0.9041 - val_loss: 0.1315 - val_acc: 0.9615
# Epoch 29/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.3024 - acc: 0.8813 - val_loss: 0.1238 - val_acc: 0.9615
# Epoch 30/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.2640 - acc: 0.9064 - val_loss: 0.1177 - val_acc: 0.9744
# Epoch 31/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.2772 - acc: 0.8904 - val_loss: 0.1147 - val_acc: 0.9744
# Epoch 32/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.2480 - acc: 0.9224 - val_loss: 0.1115 - val_acc: 0.9744
# Epoch 33/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.2220 - acc: 0.9201 - val_loss: 0.1090 - val_acc: 0.9744
# Epoch 34/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1958 - acc: 0.9269 - val_loss: 0.1058 - val_acc: 0.9744
# Epoch 35/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.2558 - acc: 0.8995 - val_loss: 0.0986 - val_acc: 0.9744
# Epoch 36/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.2404 - acc: 0.9110 - val_loss: 0.0914 - val_acc: 0.9744
# Epoch 37/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.2374 - acc: 0.9132 - val_loss: 0.0897 - val_acc: 0.9744
# Epoch 38/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1801 - acc: 0.9315 - val_loss: 0.0917 - val_acc: 0.9744
# Epoch 39/300
# 2/2 [==============================] - 0s 76ms/step - loss: 0.2079 - acc: 0.9315 - val_loss: 0.1028 - val_acc: 0.9615
# Epoch 40/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.1903 - acc: 0.9292 - val_loss: 0.1157 - val_acc: 0.9487
# Epoch 41/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.1976 - acc: 0.9315 - val_loss: 0.1307 - val_acc: 0.9615
# Epoch 42/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.1512 - acc: 0.9429 - val_loss: 0.1442 - val_acc: 0.9615
# Epoch 43/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1608 - acc: 0.9498 - val_loss: 0.1639 - val_acc: 0.9615
# Epoch 44/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.1266 - acc: 0.9612 - val_loss: 0.1846 - val_acc: 0.9615
# Epoch 45/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.1161 - acc: 0.9635 - val_loss: 0.1950 - val_acc: 0.9487
# Epoch 46/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0875 - acc: 0.9658 - val_loss: 0.1951 - val_acc: 0.9487
# Epoch 47/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0883 - acc: 0.9726 - val_loss: 0.1945 - val_acc: 0.9359
# Epoch 48/300
# 2/2 [==============================] - 0s 87ms/step - loss: 0.1075 - acc: 0.9658 - val_loss: 0.1970 - val_acc: 0.9359
# Epoch 49/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1594 - acc: 0.9566 - val_loss: 0.1984 - val_acc: 0.9359
# Epoch 50/300
# 2/2 [==============================] - 0s 88ms/step - loss: 0.0962 - acc: 0.9658 - val_loss: 0.1848 - val_acc: 0.9359
# Epoch 51/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0906 - acc: 0.9726 - val_loss: 0.1496 - val_acc: 0.9359
# Epoch 52/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0902 - acc: 0.9726 - val_loss: 0.0877 - val_acc: 0.9744
# Epoch 53/300
# 2/2 [==============================] - 0s 91ms/step - loss: 0.0567 - acc: 0.9795 - val_loss: 0.0508 - val_acc: 0.9872
# Epoch 54/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0769 - acc: 0.9772 - val_loss: 0.0492 - val_acc: 0.9872
# Epoch 55/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1200 - acc: 0.9589 - val_loss: 0.0694 - val_acc: 0.9744
# Epoch 56/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0863 - acc: 0.9703 - val_loss: 0.0440 - val_acc: 0.9872
# Epoch 57/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1168 - acc: 0.9680 - val_loss: 0.0397 - val_acc: 0.9872
# Epoch 58/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0946 - acc: 0.9726 - val_loss: 0.0529 - val_acc: 0.9872
# Epoch 59/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1322 - acc: 0.9680 - val_loss: 0.0652 - val_acc: 0.9744
# Epoch 60/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0772 - acc: 0.9772 - val_loss: 0.0631 - val_acc: 0.9872
# Epoch 61/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0900 - acc: 0.9749 - val_loss: 0.0554 - val_acc: 0.9872
# Epoch 62/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0705 - acc: 0.9795 - val_loss: 0.0542 - val_acc: 0.9872
# Epoch 63/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0764 - acc: 0.9817 - val_loss: 0.0623 - val_acc: 0.9872
# Epoch 64/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0787 - acc: 0.9726 - val_loss: 0.0674 - val_acc: 0.9872
# Epoch 65/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0900 - acc: 0.9703 - val_loss: 0.0710 - val_acc: 0.9744
# Epoch 66/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0752 - acc: 0.9795 - val_loss: 0.0711 - val_acc: 0.9872
# Epoch 67/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0432 - acc: 0.9886 - val_loss: 0.0726 - val_acc: 0.9872
# Epoch 68/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0479 - acc: 0.9817 - val_loss: 0.0900 - val_acc: 0.9744
# Epoch 69/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0561 - acc: 0.9817 - val_loss: 0.1120 - val_acc: 0.9487
# Epoch 70/300
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0561 - acc: 0.9817 - val_loss: 0.1284 - val_acc: 0.9359
# Epoch 71/300
# 2/2 [==============================] - 0s 88ms/step - loss: 0.0509 - acc: 0.9749 - val_loss: 0.1116 - val_acc: 0.9615
# Epoch 72/300
# 2/2 [==============================] - 0s 88ms/step - loss: 0.0585 - acc: 0.9817 - val_loss: 0.0805 - val_acc: 0.9615
# Epoch 73/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0382 - acc: 0.9863 - val_loss: 0.0588 - val_acc: 0.9872
# Epoch 74/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0672 - acc: 0.9749 - val_loss: 0.0435 - val_acc: 0.9872
# Epoch 75/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0688 - acc: 0.9772 - val_loss: 0.0320 - val_acc: 0.9872
# Epoch 76/300
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0703 - acc: 0.9749 - val_loss: 0.0276 - val_acc: 0.9872
# Epoch 77/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0295 - acc: 0.9863 - val_loss: 0.0265 - val_acc: 1.0000
# Epoch 78/300
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0445 - acc: 0.9863 - val_loss: 0.0286 - val_acc: 1.0000
# Epoch 79/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0729 - acc: 0.9772 - val_loss: 0.0357 - val_acc: 0.9872
# Epoch 80/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0671 - acc: 0.9795 - val_loss: 0.0535 - val_acc: 0.9872
# Epoch 81/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0465 - acc: 0.9840 - val_loss: 0.0956 - val_acc: 0.9615
# Epoch 82/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0452 - acc: 0.9886 - val_loss: 0.1334 - val_acc: 0.9487
# Epoch 83/300
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0541 - acc: 0.9795 - val_loss: 0.1553 - val_acc: 0.9231
# Epoch 84/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0700 - acc: 0.9817 - val_loss: 0.1426 - val_acc: 0.9359
# Epoch 85/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0471 - acc: 0.9863 - val_loss: 0.1131 - val_acc: 0.9615
# Epoch 86/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0543 - acc: 0.9840 - val_loss: 0.0547 - val_acc: 0.9872
# Epoch 87/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0497 - acc: 0.9817 - val_loss: 0.0342 - val_acc: 1.0000
# Epoch 88/300
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0387 - acc: 0.9795 - val_loss: 0.0350 - val_acc: 1.0000
# Epoch 89/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0264 - acc: 0.9932 - val_loss: 0.0376 - val_acc: 1.0000
# Epoch 90/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0665 - acc: 0.9863 - val_loss: 0.0381 - val_acc: 1.0000
# Epoch 91/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0359 - acc: 0.9840 - val_loss: 0.0357 - val_acc: 1.0000
# Epoch 92/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.0606 - acc: 0.9749 - val_loss: 0.0308 - val_acc: 1.0000
# Epoch 93/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.0437 - acc: 0.9817 - val_loss: 0.0364 - val_acc: 0.9872
# Epoch 94/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0230 - acc: 0.9932 - val_loss: 0.0380 - val_acc: 0.9872
# Epoch 95/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0569 - acc: 0.9840 - val_loss: 0.0471 - val_acc: 0.9872
# Epoch 96/300
# 1/2 [==============>...............] - ETA: 0s - loss: 0.0375 - acc: 0.9844

# %%
display_learning_curves(history)

# %%
#collapse
x_test = test_data.paper_id.to_numpy()
_, test_accuracy = gnn_model.evaluate(x=x_test, y=y_test, verbose=0)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")

# %%
#collapse
# First we add the N new_instances as nodes to the graph
# by appending the new_instance to node_features.
num_nodes = node_features.shape[0]
new_node_features = np.concatenate([node_features, new_instances])
# Second we add the M edges (citations) from each new node to a set
# of existing nodes in a particular subject
new_node_indices = [i + num_nodes for i in range(num_classes)]
new_citations = []
for subject_idx, group in papers.groupby("subject"):
    subject_papers = list(group.paper_id)
    # Select random x papers specific subject.
    selected_paper_indices1 = np.random.choice(subject_papers, 5)
    # Select random y papers from any subject (where y < x).
    selected_paper_indices2 = np.random.choice(list(papers.paper_id), 2)
    # Merge the selected paper indices.
    selected_paper_indices = np.concatenate(
        [selected_paper_indices1, selected_paper_indices2], axis=0
    )
    # Create edges between a citing paper idx and the selected cited papers.
    citing_paper_indx = new_node_indices[subject_idx]
    for cited_paper_idx in selected_paper_indices:
        new_citations.append([citing_paper_indx, cited_paper_idx])

new_citations = np.array(new_citations).T
new_edges = np.concatenate([edges, new_citations], axis=1)

# %%
#collapse
print("Original node_features shape:", gnn_model.node_features.shape)
print("Original edges shape:", gnn_model.edges.shape)
gnn_model.node_features = new_node_features
gnn_model.edges = new_edges
gnn_model.edge_weights = tf.ones(shape=new_edges.shape[1])
print("New node_features shape:", gnn_model.node_features.shape)
print("New edges shape:", gnn_model.edges.shape)

logits = gnn_model.predict(tf.convert_to_tensor(new_node_indices))
probabilities = keras.activations.softmax(tf.convert_to_tensor(logits)).numpy()
display_class_probabilities(probabilities)
