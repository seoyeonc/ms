# %% [markdown]
# # (시도 2) Node Classification with Graph Neural Networks
# >
#
# - toc:true
# - branch: master
# - badges: true
# - comments: false
# - author: 최서연
# - categories: [GNN]

# %% [markdown]
# ### Import

# %%
import os
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# 2022-06-17 16:55:33.680510: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-17 16:55:33.680532: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ## p=0.3

# %% [markdown]
# ### 데이터 구성

# %%
p=0.3

# %%
papers =pd.concat([pd.concat([pd.DataFrame(np.random.choice(2, 1500, p=[p,1-p]).reshape(500,3),columns=['X1','X2','X3']),
           pd.DataFrame(np.random.choice(2, 1500, p=[1-p,p]).reshape(500,3),columns=['X4','X5','X6']),
                             pd.DataFrame(np.array([['Deep learning']*500]).reshape(500,1),columns=['subject'])],axis=1),
            pd.concat([ pd.DataFrame(np.random.choice(2, 1500, p=[1-p,p]).reshape(500,3),columns=['X1','X2','X3']),
              pd.DataFrame(np.random.choice(2, 1500, p=[p,1-p]).reshape(500,3),columns=['X4','X5','X6']),
                      pd.DataFrame(np.array([['Reinforcement learning']*500]).reshape(500,1),columns=['subject'])],axis=1)],axis=0,ignore_index=True).reset_index().rename(columns={'index':'paper_id'})
papers['paper_id'] = papers['paper_id']+1
papers
# Out:
#      paper_id  X1  X2  X3  X4  X5  X6                 subject
# 0           1   1   1   1   0   1   0           Deep learning
# 1           2   1   1   1   0   1   0           Deep learning
# 2           3   0   0   1   1   0   0           Deep learning
# 3           4   0   0   1   0   1   0           Deep learning
# 4           5   1   1   0   0   0   1           Deep learning
# ..        ...  ..  ..  ..  ..  ..  ..                     ...
# 995       996   1   1   0   1   1   1  Reinforcement learning
# 996       997   0   0   0   1   1   1  Reinforcement learning
# 997       998   0   0   0   1   0   0  Reinforcement learning
# 998       999   0   1   1   1   1   0  Reinforcement learning
# 999      1000   0   0   0   1   0   1  Reinforcement learning
#
# [1000 rows x 8 columns]

# %%
# 나머지 1250 행 reinforcement learning 행 500~1000를 target, source에 임의 부여
citations =  pd.concat([pd.DataFrame(np.array([np.random.choice(range(1,501),size=(2000,1)),np.random.choice(range(1,501),size=(2000,1))]).reshape(2000,2)),
                          pd.DataFrame(np.array([np.random.choice(range(501,1001),size=(2000,1)),np.random.choice(range(501,1001),size=(2000,1))]).reshape(2000,2))],ignore_index=True).rename(columns={0:'target',1:'source'})
citations
# Out:
#       target  source
# 0         40     472
# 1        132     185
# 2         53     300
# 3        223     360
# 4         33      13
# ...      ...     ...
# 3995     566     538
# 3996     780     927
# 3997     868     647
# 3998     939     757
# 3999     751     897
#
# [4000 rows x 2 columns]

# %% [markdown]
# ### 그래프 표현

# %%
#collapse
class_values = sorted(papers["subject"].unique())
class_idx = {name: id for id, name in enumerate(class_values)}
paper_idx = {name: idx for idx, name in enumerate(sorted(papers["paper_id"].unique()))}

papers["paper_id"] = papers["paper_id"].apply(lambda name: paper_idx[name])
citations["source"] = citations["source"].apply(lambda name: paper_idx[name])
citations["target"] = citations["target"].apply(lambda name: paper_idx[name])
papers["subject"] = papers["subject"].apply(lambda value: class_idx[value])

# %%
#collapse
plt.figure(figsize=(10, 10))
colors = papers["subject"].tolist()
cora_graph = nx.from_pandas_edgelist(citations.sample(n=800))
subjects = list(papers[papers["paper_id"].isin(list(cora_graph.nodes))]["subject"])
nx.draw_spring(cora_graph, node_size=15, node_color=subjects)

# %% [markdown]
# ### Test vs Train

# %%
#collapse
train_data, test_data = [], []

for _, group_data in papers.groupby("subject"):
    # Select around 50% of the dataset for training.
    random_selection = np.random.rand(len(group_data.index)) <= 0.5
    train_data.append(group_data[random_selection])
    test_data.append(group_data[~random_selection])

train_data = pd.concat(train_data).sample(frac=1)
test_data = pd.concat(test_data).sample(frac=1)

print("Train data shape:", train_data.shape)
print("Test data shape:", test_data.shape)
# Out:
# Train data shape: (491, 8)
# Test data shape: (509, 8)

# %%
#collapse
hidden_units = [32,32]
learning_rate = 0.01
dropout_rate = 0.5
num_epochs = 300
batch_size = 256

# %%
#collapse
def run_experiment(model, x_train, y_train):
    # Compile the model.
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate),
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=[keras.metrics.SparseCategoricalAccuracy(name="acc")],
    )
    # Create an early stopping callback.
    early_stopping = keras.callbacks.EarlyStopping(
        monitor="val_acc", patience=50, restore_best_weights=True
    )
    # Fit the model.
    history = model.fit(
        x=x_train,
        y=y_train,
        epochs=num_epochs,
        batch_size=batch_size,
        validation_split=0.15,
        callbacks=[early_stopping],
    )

    return history

# %%
#collapse
def display_learning_curves(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5))

    ax1.plot(history.history["loss"])
    ax1.plot(history.history["val_loss"])
    ax1.legend(["train", "test"], loc="upper right")
    ax1.set_xlabel("Epochs")
    ax1.set_ylabel("Loss")

    ax2.plot(history.history["acc"])
    ax2.plot(history.history["val_acc"])
    ax2.legend(["train", "test"], loc="upper right")
    ax2.set_xlabel("Epochs")
    ax2.set_ylabel("Accuracy")
    plt.show()

# %%
#collapse
def create_ffn(hidden_units, dropout_rate, name=None):
    fnn_layers = []

    for units in hidden_units:
        fnn_layers.append(layers.BatchNormalization())
        fnn_layers.append(layers.Dropout(dropout_rate))
        fnn_layers.append(layers.Dense(units, activation=tf.nn.gelu))

    return keras.Sequential(fnn_layers, name=name)

# %%
#collapse
feature_names = set(papers.columns) - {"paper_id", "subject"}
num_features = len(feature_names)
num_classes = len(class_idx)

# Create train and test features as a numpy array.
x_train = train_data[feature_names].to_numpy()
x_test = test_data[feature_names].to_numpy()
# Create train and test targets as a numpy array.
y_train = train_data["subject"]
y_test = test_data["subject"]

# %%
#collapse
def create_baseline_model(hidden_units, num_classes, dropout_rate=0.2):
    inputs = layers.Input(shape=(num_features,), name="input_features")
    x = create_ffn(hidden_units, dropout_rate, name=f"ffn_block1")(inputs)
    for block_idx in range(4):
        # Create an FFN block.
        x1 = create_ffn(hidden_units, dropout_rate, name=f"ffn_block{block_idx + 2}")(x)
        # Add skip connection.
        x = layers.Add(name=f"skip_connection{block_idx + 2}")([x, x1])
    # Compute logits.
    logits = layers.Dense(num_classes, name="logits")(x)
    # Create the model.
    return keras.Model(inputs=inputs, outputs=logits, name="baseline")


baseline_model = create_baseline_model(hidden_units, num_classes, dropout_rate)
baseline_model.summary()
# Out:
# Model: "baseline"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_features (InputLayer)    [(None, 6)]          0           []
#
#  ffn_block1 (Sequential)        (None, 32)           1432        ['input_features[0][0]']
#
#  ffn_block2 (Sequential)        (None, 32)           2368        ['ffn_block1[0][0]']
#
#  skip_connection2 (Add)         (None, 32)           0           ['ffn_block1[0][0]',
#                                                                   'ffn_block2[0][0]']
#
#  ffn_block3 (Sequential)        (None, 32)           2368        ['skip_connection2[0][0]']
#
#  skip_connection3 (Add)         (None, 32)           0           ['skip_connection2[0][0]',
#                                                                   'ffn_block3[0][0]']
#
#  ffn_block4 (Sequential)        (None, 32)           2368        ['skip_connection3[0][0]']
#
#  skip_connection4 (Add)         (None, 32)           0           ['skip_connection3[0][0]',
#                                                                   'ffn_block4[0][0]']
#
#  ffn_block5 (Sequential)        (None, 32)           2368        ['skip_connection4[0][0]']
#
#  skip_connection5 (Add)         (None, 32)           0           ['skip_connection4[0][0]',
#                                                                   'ffn_block5[0][0]']
#
#  logits (Dense)                 (None, 2)            66          ['skip_connection5[0][0]']
#
# ==================================================================================================
# Total params: 10,970
# Trainable params: 10,382
# Non-trainable params: 588
# __________________________________________________________________________________________________

# %%
#collapse_output
history = run_experiment(baseline_model, x_train, y_train)
# Out:
# Epoch 1/300
# 2/2 [==============================] - 2s 283ms/step - loss: 1.0684 - acc: 0.5252 - val_loss: 0.6528 - val_acc: 0.6216
# Epoch 2/300
# 2/2 [==============================] - 0s 39ms/step - loss: 0.9521 - acc: 0.6331 - val_loss: 0.6122 - val_acc: 0.8378
# Epoch 3/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.9054 - acc: 0.6331 - val_loss: 0.5989 - val_acc: 0.7838
# Epoch 4/300
# 2/2 [==============================] - 0s 40ms/step - loss: 0.8535 - acc: 0.6619 - val_loss: 0.5999 - val_acc: 0.7432
# Epoch 5/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.7777 - acc: 0.6667 - val_loss: 0.5949 - val_acc: 0.7703
# Epoch 6/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.7181 - acc: 0.6667 - val_loss: 0.5916 - val_acc: 0.7838
# Epoch 7/300
# 2/2 [==============================] - 0s 46ms/step - loss: 0.6917 - acc: 0.6811 - val_loss: 0.5908 - val_acc: 0.7838
# Epoch 8/300
# 2/2 [==============================] - 0s 40ms/step - loss: 0.
300
# 2/2 [==============================] - 0s 45ms/step - loss: 0.5313 - acc: 0.7458 - val_loss: 0.5168 - val_acc: 0.7973
# Epoch 42/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.5002 - acc: 0.7554 - val_loss: 0.5193 - val_acc: 0.7973
# Epoch 43/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5278 - acc: 0.7338 - val_loss: 0.5225 - val_acc: 0.7973
# Epoch 44/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4660 - acc: 0.7722 - val_loss: 0.5249 - val_acc: 0.7703
# Epoch 45/300
# 2/2 [==============================] - 0s 50ms/step - loss: 0.4623 - acc: 0.7482 - val_loss: 0.5242 - val_acc: 0.7703
# Epoch 46/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.4950 - acc: 0.7722 - val_loss: 0.5239 - val_acc: 0.7838
# Epoch 47/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.5052 - acc: 0.7578 - val_loss: 0.5231 - val_acc: 0.7838
# Epoch 48/300
# 2/2 [==============================] - 0s 46ms/step - loss: 0.5076 - acc: 0.7410 - val_loss: 0.5199 - val_acc: 0.7703
# Epoch 49/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.4579 - acc: 0.8106 - val_loss: 0.5140 - val_acc: 0.7703
# Epoch 50/300
# 2/2 [==============================] - 0s 41ms/step - loss: 0.5100 - acc: 0.7482 - val_loss: 0.5077 - val_acc: 0.7838
# Epoch 51/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.5254 - acc: 0.7410 - val_loss: 0.5045 - val_acc: 0.7973
# Epoch 52/300
# 2/2 [==============================] - 0s 58ms/step - loss: 0.4941 - acc: 0.7626 - val_loss: 0.5017 - val_acc: 0.7973

# %%
display_learning_curves(history)

# %%
#collapse
_, test_accuracy = baseline_model.evaluate(x=x_test, y=y_test, verbose=0)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 81.53%

# %% [markdown]
# #### p = 0.3 Test accuracy: 82.35%

# %% [markdown]
# ### baseline 모델 예측

# %%
#collapse
def generate_random_instances(num_instances):
    token_probability = x_train.mean(axis=0)
    instances = []
    for _ in range(num_instances):
        probabilities = np.random.uniform(size=len(token_probability))
        instance = (probabilities <= token_probability).astype(int)
        instances.append(instance)

    return np.array(instances)


def display_class_probabilities(probabilities):
    for instance_idx, probs in enumerate(probabilities):
        print(f"Instance {instance_idx + 1}:")
        for class_idx, prob in enumerate(probs):
            print(f"- {class_values[class_idx]}: {round(prob * 100, 2)}%")

# %%
#collapse
new_instances = generate_random_instances(num_classes)
logits = baseline_model.predict(new_instances)
probabilities = keras.activations.softmax(tf.convert_to_tensor(logits)).numpy()
display_class_probabilities(probabilities)
# Out:
# Instance 1:
# - Deep learning: 40.74%
# - Reinforcement learning: 59.26%
# Instance 2:
# - Deep learning: 35.28%
# - Reinforcement learning: 64.72%

# %%
#collapse
# Create an edges array (sparse adjacency matrix) of shape [2, num_edges].
edges = citations[["source", "target"]].to_numpy().T
# Create an edge weights array of ones.
edge_weights = tf.ones(shape=edges.shape[1])
# Create a node features array of shape [num_nodes, num_features].
node_features = tf.cast(
    papers.sort_values("paper_id")[feature_names].to_numpy(), dtype=tf.dtypes.float32
)
# Create graph info tuple with node_features, edges, and edge_weights.
graph_info = (node_features, edges, edge_weights)

print("Edges shape:", edges.shape)
print("Edge weight shape:", edge_weights.shape)
print("Nodes shape:", node_features.shape)
# Out:
# Edges shape: (2, 4000)
# Edge weight shape: (4000,)
# Nodes shape: (1000, 6)

# %%
#collapse
class GraphConvLayer(layers.Layer):
    def __init__(
        self,
        hidden_units,
        dropout_rate=0.2,
        aggregation_type="mean",
        combination_type="concat",
        normalize=False,
        *args,
        **kwargs,
    ):
        super(GraphConvLayer, self).__init__(*args, **kwargs)

        self.aggregation_type = aggregation_type
        self.combination_type = combination_type
        self.normalize = normalize

        self.ffn_prepare = create_ffn(hidden_units, dropout_rate)
        if self.combination_type == "gated":
            self.update_fn = layers.GRU(
                units=hidden_units,
                activation="tanh",
                recurrent_activation="sigmoid",
                dropout=dropout_rate,
                return_state=True,
                recurrent_dropout=dropout_rate,
            )
        else:
            self.update_fn = create_ffn(hidden_units, dropout_rate)

    def prepare(self, node_repesentations, weights=None):
        # node_repesentations shape is [num_edges, embedding_dim].
        messages = self.ffn_prepare(node_repesentations)
        if weights is not None:
            messages = messages * tf.expand_dims(weights, -1)
        return messages

    def aggregate(self, node_indices, neighbour_messages):
        # node_indices shape is [num_edges].
        # neighbour_messages shape: [num_edges, representation_dim].
        num_nodes = tf.math.reduce_max(node_indices) + 1
        if self.aggregation_type == "sum":
            aggregated_message = tf.math.unsorted_segment_sum(
                neighbour_messages, node_indices, num_segments=num_nodes
            )
        elif self.aggregation_type == "mean":
            aggregated_message = tf.math.unsorted_segment_mean(
                neighbour_messages, node_indices, num_segments=num_nodes
            )
        elif self.aggregation_type == "max":
            aggregated_message = tf.math.unsorted_segment_max(
                neighbour_messages, node_indices, num_segments=num_nodes
            )
        else:
            raise ValueError(f"Invalid aggregation type: {self.aggregation_type}.")

        return aggregated_message

    def update(self, node_repesentations, aggregated_messages):
        # node_repesentations shape is [num_nodes, representation_dim].
        # aggregated_messages shape is [num_nodes, representation_dim].
        if self.combination_type == "gru":
            # Create a sequence of two elements for the GRU layer.
            h = tf.stack([node_repesentations, aggregated_messages], axis=1)
        elif self.combination_type == "concat":
            # Concatenate the node_repesentations and aggregated_messages.
            h = tf.concat([node_repesentations, aggregated_messages], axis=1)
        elif self.combination_type == "add":
            # Add node_repesentations and aggregated_messages.
            h = node_repesentations + aggregated_messages
        else:
            raise ValueError(f"Invalid combination type: {self.combination_type}.")

        # Apply the processing function.
        node_embeddings = self.update_fn(h)
        if self.combination_type == "gru":
            node_embeddings = tf.unstack(node_embeddings, axis=1)[-1]

        if self.normalize:
            node_embeddings = tf.nn.l2_normalize(node_embeddings, axis=-1)
        return node_embeddings

    def call(self, inputs):
        """Process the inputs to produce the node_embeddings.

        inputs: a tuple of three elements: node_repesentations, edges, edge_weights.
        Returns: node_embeddings of shape [num_nodes, representation_dim].
        """

        node_repesentations, edges, edge_weights = inputs
        # Get node_indices (source) and neighbour_indices (target) from edges.
        node_indices, neighbour_indices = edges[0], edges[1]
        # neighbour_repesentations shape is [num_edges, representation_dim].
        neighbour_repesentations = tf.gather(node_repesentations, neighbour_indices)

        # Prepare the messages of the neighbours.
        neighbour_messages = self.prepare(neighbour_repesentations, edge_weights)
        # Aggregate the neighbour messages.
        aggregated_messages = self.aggregate(node_indices, neighbour_messages)
        # Update the node embedding with the neighbour messages.
        return self.update(node_repesentations, aggregated_messages)

# %%
#collapse
class GNNNodeClassifier(tf.keras.Model):
    def __init__(
        self,
        graph_info,
        num_classes,
        hidden_units,
        aggregation_type="sum",
        combination_type="concat",
        dropout_rate=0.2,
        normalize=True,
        *args,
        **kwargs,
    ):
        super(GNNNodeClassifier, self).__init__(*args, **kwargs)

        # Unpack graph_info to three elements: node_features, edges, and edge_weight.
        node_features, edges, edge_weights = graph_info
        self.node_features = node_features
        self.edges = edges
        self.edge_weights = edge_weights
        # Set edge_weights to ones if not provided.
        if self.edge_weights is None:
            self.edge_weights = tf.ones(shape=edges.shape[1])
        # Scale edge_weights to sum to 1.
        self.edge_weights = self.edge_weights / tf.math.reduce_sum(self.edge_weights)

        # Create a process layer.
        self.preprocess = create_ffn(hidden_units, dropout_rate, name="preprocess")
        # Create the first GraphConv layer.
        self.conv1 = GraphConvLayer(
            hidden_units,
            dropout_rate,
            aggregation_type,
            combination_type,
            normalize,
            name="graph_conv1",
        )
        # Create the second GraphConv layer.
        self.conv2 = GraphConvLayer(
            hidden_units,
            dropout_rate,
            aggregation_type,
            combination_type,
            normalize,
            name="graph_conv2",
        )
        # Create a postprocess layer.
        self.postprocess = create_ffn(hidden_units, dropout_rate, name="postprocess")
        # Create a compute logits layer.
        self.compute_logits = layers.Dense(units=num_classes, name="logits")

    def call(self, input_node_indices):
        # Preprocess the node_features to produce node representations.
        x = self.preprocess(self.node_features)
        # Apply the first graph conv layer.
        x1 = self.conv1((x, self.edges, self.edge_weights))
        # Skip connection.
        x = x1 + x
        # Apply the second graph conv layer.
        x2 = self.conv2((x, self.edges, self.edge_weights))
        # Skip connection.
        x = x2 + x
        # Postprocess node embedding.
        x = self.postprocess(x)
        # Fetch node embeddings for the input node_indices.
        node_embeddings = tf.gather(x, input_node_indices)
        # Compute logits
        return self.compute_logits(node_embeddings)

# %%
#collapse
gnn_model = GNNNodeClassifier(
    graph_info=graph_info,
    num_classes=num_classes,
    hidden_units=hidden_units,
    dropout_rate=dropout_rate,
    name="gnn_model",
)

print("GNN output shape:", gnn_model([1, 10, 100]))

gnn_model.summary()
# Out:
# GNN output shape: tf.Tensor(
# [[ 0.02291587  0.0006361 ]
#  [-0.03478812  0.03772844]
#  [-0.04357063 -0.12569514]], shape=(3, 2), dtype=float32)
# Model: "gnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  preprocess (Sequential)     (1000, 32)                1432
#
#  graph_conv1 (GraphConvLayer  multiple                 5888
#  )
#
#  graph_conv2 (GraphConvLayer  multiple                 5888
#  )
#
#  postprocess (Sequential)    (1000, 32)                2368
#
#  logits (Dense)              multiple                  66
#
# =================================================================
# Total params: 15,642
# Trainable params: 14,798
# Non-trainable params: 844
# _________________________________________________________________

# %%
#collapse_Output
x_train = train_data.paper_id.to_numpy()
history = run_experiment(gnn_model, x_train, y_train)
# Out:
# Epoch 1/300
# 2/2 [==============================] - 3s 349ms/step - loss: 0.9040 - acc: 0.5108 - val_loss: 0.6786 - val_acc: 0.5405
# Epoch 2/300
# 2/2 [==============================] - 0s 71ms/step - loss: 0.7589 - acc: 0.5324 - val_loss: 0.6846 - val_acc: 0.4595
# Epoch 3/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.7327 - acc: 0.5755 - val_loss: 0.6778 - val_acc: 0.4595
# Epoch 4/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.6997 - acc: 0.5875 - val_loss: 0.6655 - val_acc: 0.5405
# Epoch 5/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.6753 - acc: 0.6067 - val_loss: 0.6494 - val_acc: 0.6622
# Epoch 6/300
# 2/2 [==============================] - 0s 96ms/step - loss: 0.6794 - acc: 0.6139 - val_loss: 0.6329 - val_acc: 0.7162
# Epoch 7/300
# 2/2 [==============================] - 0s 87ms/step - loss: 0.5741 - acc: 0.7026 - val_loss: 0.6145 - val_acc: 0.8108
# Epoch 8/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.6187 - acc: 0.6643 - val_loss: 0.5953 - val_acc: 0.7973
# Epoch 9/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.5945 - acc: 0.6763 - val_loss: 0.5744 - val_acc: 0.8108
# Epoch 10/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.5318 - acc: 0.7338 - val_loss: 0.5488 - val_acc: 0.8108
# Epoch 11/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.5325 - acc: 0.7386 - val_loss: 0.5211 - val_acc: 0.8108
# Epoch 12/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.5681 - acc: 0.7362 - val_loss: 0.4952 - val_acc: 0.7973
# Epoch 13/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.5519 - acc: 0.7482 - val_loss: 0.4774 - val_acc: 0.7973
# Epoch 14/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.5389 - acc: 0.7290 - val_loss: 0.4682 - val_acc: 0.7703
# Epoch 15/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.5388 - acc: 0.7506 - val_loss: 0.4652 - val_acc: 0.7973
# Epoch 16/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.5249 - acc: 0.7458 - val_loss: 0.4669 - val_acc: 0.7838
# Epoch 17/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.5703 - acc: 0.7122 - val_loss: 0.4714 - val_acc: 0.7838
# Epoch 18/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.5563 - acc: 0.7530 - val_loss: 0.4787 - val_acc: 0.7973
# Epoch 19/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.5450 - acc: 0.7242 - val_loss: 0.4855 - val_acc: 0.7973
# Epoch 20/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.5336 - acc: 0.7386 - val_loss: 0.4881 - val_acc: 0.7973
# Epoch 21/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0.4962 - acc: 0.7602 - val_loss: 0.4843 - val_acc: 0.7973
# Epoch 22/300
# 2/2 [==============================] - 0s 89ms/step - loss: 0.5315 - acc: 0.7386 - val_loss: 0.4779 - val_acc: 0.7838
# Epoch 23/300
# 2/2 [==============================] - 0s 89ms/step - loss: 0.5335 - acc: 0.7410 - val_loss: 0.4698 - val_acc: 0.7973
# Epoch 24/300
# 2/2 [==============================] - 0s 90ms/step - loss: 0
300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0318 - acc: 0.9928 - val_loss: 0.0673 - val_acc: 0.9730
# Epoch 219/300
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0415 - acc: 0.9832 - val_loss: 0.0690 - val_acc: 0.9459
# Epoch 220/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0367 - acc: 0.9808 - val_loss: 0.0664 - val_acc: 0.9730
# Epoch 221/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0338 - acc: 0.9880 - val_loss: 0.0660 - val_acc: 0.9730
# Epoch 222/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0449 - acc: 0.9880 - val_loss: 0.0747 - val_acc: 0.9459
# Epoch 223/300
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0567 - acc: 0.9784 - val_loss: 0.0753 - val_acc: 0.9459
# Epoch 224/300
# 2/2 [==============================] - 0s 96ms/step - loss: 0.0881 - acc: 0.9736 - val_loss: 0.0748 - val_acc: 0.9459
# Epoch 225/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0585 - acc: 0.9808 - val_loss: 0.0746 - val_acc: 0.9459
# Epoch 226/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0451 - acc: 0.9832 - val_loss: 0.0732 - val_acc: 0.9459
# Epoch 227/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0792 - acc: 0.9736 - val_loss: 0.0706 - val_acc: 0.9595
# Epoch 228/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0403 - acc: 0.9856 - val_loss: 0.0699 - val_acc: 0.9595
# Epoch 229/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0390 - acc: 0.9904 - val_loss: 0.0742 - val_acc: 0.9459
# Epoch 230/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.0383 - acc: 0.9856 - val_loss: 0.0860 - val_acc: 0.9459
# Epoch 231/300
# 2/2 [==============================] - 0s 87ms/step - loss: 0.0422 - acc: 0.9808 - val_loss: 0.0901 - val_acc: 0.9459
# Epoch 232/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0342 - acc: 0.9880 - val_loss: 0.0906 - val_acc: 0.9459
# Epoch 233/300
# 2/2 [==============================] - 0s 92ms/step - loss: 0.0334 - acc: 0.9904 - val_loss: 0.0909 - val_acc: 0.9459

# %%
display_learning_curves(history)

# %%
#collapse
x_test = test_data.paper_id.to_numpy()
_, test_accuracy = gnn_model.evaluate(x=x_test, y=y_test, verbose=0)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 98.62%

# %% [markdown]
# #### p = 0.3 Test accuracy: 93.07%

# %%
#collapse
# First we add the N new_instances as nodes to the graph
# by appending the new_instance to node_features.
num_nodes = node_features.shape[0]
new_node_features = np.concatenate([node_features, new_instances])
# Second we add the M edges (citations) from each new node to a set
# of existing nodes in a particular subject
new_node_indices = [i + num_nodes for i in range(num_classes)]
new_citations = []
for subject_idx, group in papers.groupby("subject"):
    subject_papers = list(group.paper_id)
    # Select random x papers specific subject.
    selected_paper_indices1 = np.random.choice(subject_papers, 5)
    # Select random y papers from any subject (where y < x).
    selected_paper_indices2 = np.random.choice(list(papers.paper_id), 2)
    # Merge the selected paper indices.
    selected_paper_indices = np.concatenate(
        [selected_paper_indices1, selected_paper_indices2], axis=0
    )
    # Create edges between a citing paper idx and the selected cited papers.
    citing_paper_indx = new_node_indices[subject_idx]
    for cited_paper_idx in selected_paper_indices:
        new_citations.append([citing_paper_indx, cited_paper_idx])

new_citations = np.array(new_citations).T
new_edges = np.concatenate([edges, new_citations], axis=1)

# %%
#collapse
print("Original node_features shape:", gnn_model.node_features.shape)
print("Original edges shape:", gnn_model.edges.shape)
gnn_model.node_features = new_node_features
gnn_model.edges = new_edges
gnn_model.edge_weights = tf.ones(shape=new_edges.shape[1])
print("New node_features shape:", gnn_model.node_features.shape)
print("New edges shape:", gnn_model.edges.shape)

logits = gnn_model.predict(tf.convert_to_tensor(new_node_indices))
probabilities = keras.activations.softmax(tf.convert_to_tensor(logits)).numpy()
display_class_probabilities(probabilities)
# Out:
# Original node_features shape: (1000, 6)
# Original edges shape: (2, 4000)
# New node_features shape: (1002, 6)
# New edges shape: (2, 4014)
# Instance 1:
# - Deep learning: 98.9%
# - Reinforcement learning: 1.1%
# Instance 2:
# - Deep learning: 0.0%
# - Reinforcement learning: 100.0%

# %% [markdown]
# ## p=0.2

# %% [markdown]
# ### 데이터 구성

# %%
p=0.2

# %%
papers =pd.concat([pd.concat([pd.DataFrame(np.random.choice(2, 1500, p=[p,1-p]).reshape(500,3),columns=['X1','X2','X3']),
           pd.DataFrame(np.random.choice(2, 1500, p=[1-p,p]).reshape(500,3),columns=['X4','X5','X6']),
                             pd.DataFrame(np.array([['Deep learning']*500]).reshape(500,1),columns=['subject'])],axis=1),
            pd.concat([ pd.DataFrame(np.random.choice(2, 1500, p=[1-p,p]).reshape(500,3),columns=['X1','X2','X3']),
              pd.DataFrame(np.random.choice(2, 1500, p=[p,1-p]).reshape(500,3),columns=['X4','X5','X6']),
                      pd.DataFrame(np.array([['Reinforcement learning']*500]).reshape(500,1),columns=['subject'])],axis=1)],axis=0,ignore_index=True).reset_index().rename(columns={'index':'paper_id'})
papers['paper_id'] = papers['paper_id']+1

# %%
# 나머지 1250 행 reinforcement learning 행 500~1000를 target, source에 임의 부여
citations =  pd.concat([pd.DataFrame(np.array([np.random.choice(range(1,501),size=(2000,1)),np.random.choice(range(1,501),size=(2000,1))]).reshape(2000,2)),
                          pd.DataFrame(np.array([np.random.choice(range(501,1001),size=(2000,1)),np.random.choice(range(501,1001),size=(2000,1))]).reshape(2000,2))],ignore_index=True).rename(columns={0:'target',1:'source'})

# %% [markdown]
# ### 그래프 표현

# %%
#collapse
class_values = sorted(papers["subject"].unique())
class_idx = {name: id for id, name in enumerate(class_values)}
paper_idx = {name: idx for idx, name in enumerate(sorted(papers["paper_id"].unique()))}

papers["paper_id"] = papers["paper_id"].apply(lambda name: paper_idx[name])
citations["source"] = citations["source"].apply(lambda name: paper_idx[name])
citations["target"] = citations["target"].apply(lambda name: paper_idx[name])
papers["subject"] = papers["subject"].apply(lambda value: class_idx[value])

# %%
#collapse
plt.figure(figsize=(10, 10))
colors = papers["subject"].tolist()
cora_graph = nx.from_pandas_edgelist(citations.sample(n=800))
subjects = list(papers[papers["paper_id"].isin(list(cora_graph.nodes))]["subject"])
nx.draw_spring(cora_graph, node_size=15, node_color=subjects)

#
_, test_accuracy = baseline_model.evaluate(x=x_test, y=y_test, verbose=0)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 93.31%

# %% [markdown]
# #### p=2 Test accuracy: 93.55%

# %% [markdown]
# ### baseline 모델 예측

# %%
#collapse
new_instances = generate_random_instances(num_classes)
logits = baseline_model.predict(new_instances)
probabilities = keras.activations.softmax(tf.convert_to_tensor(logits)).numpy()
display_class_probabilities(probabilities)
# Out:
# Instance 1:
# - Deep learning: 53.7%
# - Reinforcement learning: 46.3%
# Instance 2:
# - Deep learning: 48.66%
# - Reinforcement learning: 51.34%

# %%
#collapse
# Create an edges array (sparse adjacency matrix) of shape [2, num_edges].
edges = citations[["source", "target"]].to_numpy().T
# Create an edge weights array of ones.
edge_weights = tf.ones(shape=edges.shape[1])
# Create a node features array of shape [num_nodes, num_features].
node_features = tf.cast(
    papers.sort_values("paper_id")[feature_names].to_numpy(), dtype=tf.dtypes.float32
)
# Create graph info tuple with node_features, edges, and edge_weights.
graph_info = (node_features, edges, edge_weights)

print("Edges shape:", edges.shape)
print("Edge weight shape:", edge_weights.shape)
print("Nodes shape:", node_features.shape)
# Out:
# Edges shape: (2, 4000)
# Edge weight shape: (4000,)
# Nodes shape: (1000, 6)

# %%
#collapse
gnn_model = GNNNodeClassifier(
    graph_info=graph_info,
    num_classes=num_classes,
    hidden_units=hidden_units,
    dropout_rate=dropout_rate,
    name="gnn_model",
)

print("GNN output shape:", gnn_model([1, 10, 100]))

gnn_model.summary()
# Out:
# GNN output shape: tf.Tensor(
# [[-0.06295846 -0.01136803]
#  [ 0.00968727 -0.00471489]
#  [ 0.00965237 -0.00473109]], shape=(3, 2), dtype=float32)
# Model: "gnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  preprocess (Sequential)     (1000, 32)                1432
#
#  graph_conv1 (GraphConvLayer  multiple                 5888
#  )
#
#  graph_conv2 (GraphConvLayer  multiple                 5888
#  )
#
#  postprocess (Sequential)    (1000, 32)                2368
#
#  logits (Dense)              multiple                  66
#
# =================================================================
# Total params: 15,642
# Trainable params: 14,798
# Non-trainable params: 844
# _________________________________________________________________

# %%
#collapse_Output
x_train = train_data.paper_id.to_numpy()
history = run_experiment(gnn_model, x_train, y_train)
# Out:
# Epoch 1/300
# 2/2 [==============================] - 2s 335ms/step - loss: 0.8963 - acc: 0.4889 - val_loss: 0.6761 - val_acc: 0.4583
# Epoch 2/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.7299 - acc: 0.5778 - val_loss: 0.6474 - val_acc: 0.8194
# Epoch 3/300
# 2/2 [==============================] - 0s 75ms/step - loss: 0.6518 - acc: 0.6272 - val_loss: 0.6094 - val_acc: 0.8889
# Epoch 4/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.5902 - acc: 0.6840 - val_loss: 0.5704 - val_acc: 0.9028
# Epoch 5/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.5936 - acc: 0.7136 - val_loss: 0.5201 - val_acc: 0.9167
# Epoch 6/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.5943 - acc: 0.6938 - val_loss: 0.4646 - val_acc: 0.9306
# Epoch 7/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.4873 - acc: 0.7753 - val_loss: 0.4122 - val_acc: 0.9167
# Epoch 8/300
# 2/2 [==============================] - 0s 74ms/step - loss: 0.4920 - acc: 0.7556 - val_loss: 0.3694 - val_acc: 0.8889
# Epoch 9/300
# 2/2 [==============================] - 0s 71ms/step - loss: 0.4613 - acc: 0.8025 - val_loss: 0.3426 - val_acc: 0.8611
# Epoch 10/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.4591 - acc: 0.8123 - val_loss: 0.3284 - val_acc: 0.8611
# Epoch 11/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.4977 - acc: 0.8000 - val_loss: 0.3227 - val_acc: 0.8472
# Epoch 12/300
# 2/2 [==============================] - 0s 76ms/step - loss: 0.4234 - acc: 0.8025 - val_loss: 0.3210 - val_acc: 0.8611
# Epoch 13/300
# 2/2 [==============================] - 0s 72ms/step - loss: 0.4152 - acc: 0.8049 - val_loss: 0.3165 - val_acc: 0.8611
# Epoch 14/300
# 2/2 [==============================] - 0s 74ms/step - loss: 0.3900 - acc: 0.8370 - val_loss: 0.3094 - val_acc: 0.8750
# Epoch 15/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.3920 - acc: 0.8222 - val_loss: 0.3052 - val_acc: 0.8750
# Epoch 16/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.4112 - acc: 0.8272 - val_loss: 0.3100 - val_acc: 0.8750
# Epoch 17/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.4402 - acc: 0.8049 - val_loss: 0.3118 - val_acc: 0.8750
# Epoch 18/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.3496 - acc: 0.8519 - val_loss: 0.3081 - val_acc: 0.8750
# Epoch 19/300
# 2/2 [==============================] - 0s 78ms/step - loss: 0.4078 - acc: 0.8395 - val_loss: 0.2981 - val_acc: 0.8750
# Epoch 20/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.3572 - acc: 0.8617 - val_loss: 0.2828 - val_acc: 0.8750
# Epoch 21/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.3545 - acc: 0.8543 - val_loss: 0.2682 - val_acc: 0.8750
# Epoch 22/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.4014 - acc: 0.8222 - val_loss: 0.2621 - val_acc: 0.8750
# Epoch 23/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.4050 - acc: 0.8173 - val_loss: 0.2604 - val_acc: 0.8750
# Epoch 24/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.3736 - acc: 0.8716 - val_loss: 0.2595 - val_acc: 0.9028
# Epoch 25/300
# 2/2 [==============================] - 0s 87ms/step - loss: 0
300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0785 - acc: 0.9654 - val_loss: 1.5329 - val_acc: 0.5417
# Epoch 58/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0841 - acc: 0.9728 - val_loss: 1.2600 - val_acc: 0.5417
# Epoch 59/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0847 - acc: 0.9778 - val_loss: 0.9669 - val_acc: 0.5417
# Epoch 60/300
# 2/2 [==============================] - 0s 68ms/step - loss: 0.0816 - acc: 0.9679 - val_loss: 0.6987 - val_acc: 0.5417
# Epoch 61/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1186 - acc: 0.9728 - val_loss: 0.6372 - val_acc: 0.5694
# Epoch 62/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0973 - acc: 0.9654 - val_loss: 0.6270 - val_acc: 0.5694
# Epoch 63/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.1106 - acc: 0.9630 - val_loss: 0.6327 - val_acc: 0.5694
# Epoch 64/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1030 - acc: 0.9654 - val_loss: 0.5330 - val_acc: 0.5972
# Epoch 65/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0523 - acc: 0.9877 - val_loss: 0.4629 - val_acc: 0.6528
# Epoch 66/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0531 - acc: 0.9852 - val_loss: 0.4370 - val_acc: 0.6944
# Epoch 67/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.0705 - acc: 0.9753 - val_loss: 0.4427 - val_acc: 0.6806
# Epoch 68/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0328 - acc: 0.9926 - val_loss: 0.4506 - val_acc: 0.6667
# Epoch 69/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.1021 - acc: 0.9753 - val_loss: 0.4489 - val_acc: 0.6667
# Epoch 70/300
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1302 - acc: 0.9580 - val_loss: 0.4491 - val_acc: 0.6667
# Epoch 71/300
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0834 - acc: 0.9704 - val_loss: 0.4724 - val_acc: 0.6528
# Epoch 72/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.0707 - acc: 0.9753 - val_loss: 0.5229 - val_acc: 0.5972
# Epoch 73/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.0697 - acc: 0.9753 - val_loss: 0.5525 - val_acc: 0.5694
# Epoch 74/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0827 - acc: 0.9753 - val_loss: 0.5853 - val_acc: 0.5556
# Epoch 75/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.0411 - acc: 0.9877 - val_loss: 0.6286 - val_acc: 0.5417
# Epoch 76/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.0931 - acc: 0.9654 - val_loss: 0.6134 - val_acc: 0.5694
# Epoch 77/300
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0559 - acc: 0.9827 - val_loss: 0.4905 - val_acc: 0.6806
# Epoch 78/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.0652 - acc: 0.9728 - val_loss: 0.3945 - val_acc: 0.7500
# Epoch 79/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.0684 - acc: 0.9753 - val_loss: 0.3717 - val_acc: 0.7639

# %%
display_learning_curves(history)

# %%
#collapse
x_test = test_data.paper_id.to_numpy()
_, test_accuracy = gnn_model.evaluate(x=x_test, y=y_test, verbose=0)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 92.73%

# %% [markdown]
# #### p=0.2 Test accuracy: 97.58%

# %%
#collapse
# First we add the N new_instances as nodes to the graph
# by appending the new_instance to node_features.
num_nodes = node_features.shape[0]
new_node_features = np.concatenate([node_features, new_instances])
# Second we add the M edges (citations) from each new node to a set
# of existing nodes in a particular subject
new_node_indices = [i + num_nodes for i in range(num_classes)]
new_citations = []
for subject_idx, group in papers.groupby("subject"):
    subject_papers = list(group.paper_id)
    # Select random x papers specific subject.
    selected_paper_indices1 = np.random.choice(subject_papers, 5)
    # Select random y papers from any subject (where y < x).
    selected_paper_indices2 = np.random.choice(list(papers.paper_id), 2)
    # Merge the selected paper indices.
    selected_paper_indices = np.concatenate(
        [selected_paper_indices1, selected_paper_indices2], axis=0
    )
    # Create edges between a citing paper idx and the selected cited papers.
    citing_paper_indx = new_node_indices[subject_idx]
    for cited_paper_idx in selected_paper_indices:
        new_citations.append([citing_paper_indx, cited_paper_idx])

new_citations = np.array(new_citations).T
new_edges = np.concatenate([edges, new_citations], axis=1)

# %%
#collapse
print("Original node_features shape:", gnn_model.node_features.shape)
print("Original edges shape:", gnn_model.edges.shape)
gnn_model.node_features = new_node_features
gnn_model.edges = new_edges
gnn_model.edge_weights = tf.ones(shape=new_edges.shape[1])
print("New node_features shape:", gnn_model.node_features.shape)
print("New edges shape:", gnn_model.edges.shape)

logits = gnn_model.predict(tf.convert_to_tensor(new_node_indices))
probabilities = keras.activations.softmax(tf.convert_to_tensor(logits)).numpy()
display_class_probabilities(probabilities)
# Out:
# Original node_features shape: (1000, 6)
# Original edges shape: (2, 4000)
# New node_features shape: (1002, 6)
# New edges shape: (2, 4014)
# Instance 1:
# - Deep learning: 16.11%
# - Reinforcement learning: 83.89%
# Instance 2:
# - Deep learning: 9.37%
# - Reinforcement learning: 90.63%

# %% [markdown]
# ## p=0.4

# %% [markdown]
# ### 데이터 구성

# %%
p=0.4

# %%
papers =pd.concat([pd.concat([pd.DataFrame(np.random.choice(2, 1500, p=[p,1-p]).reshape(500,3),columns=['X1','X2','X3']),
           pd.DataFrame(np.random.choice(2, 1500, p=[1-p,p]).reshape(500,3),columns=['X4','X5','X6']),
                             pd.DataFrame(np.array([['Deep learning']*500]).reshape(500,1),columns=['subject'])],axis=1),
            pd.concat([ pd.DataFrame(np.random.choice(2, 1500, p=[1-p,p]).reshape(500,3),columns=['X1','X2','X3']),
              pd.DataFrame(np.random.choice(2, 1500, p=[p,1-p]).reshape(500,3),columns=['X4','X5','X6']),
                      pd.DataFrame(np.array([['Reinforcement learning']*500]).reshape(500,1),columns=['subject'])],axis=1)],axis=0,ignore_index=True).reset_index().rename(columns={'index':'paper_id'})
papers['paper_id'] = papers['paper_id']+1

# %%
# 나머지 1250 행 reinforcement learning 행 500~1000를 target, source에 임의 부여
citations =  pd.concat([pd.DataFrame(np.array([np.random.choice(range(1,501),size=(2000,1)),np.random.choice(range(1,501),size=(2000,1))]).reshape(2000,2)),
                          pd.DataFrame(np.array([np.random.choice(range(501,1001),size=(2000,1)),np.random.choice(range(501,1001),size=(2000,1))]).reshape(2000,2))],ignore_index=True).rename(columns={0:'target',1:'source'})

# %% [markdown]
# ### 그래프 표현

# %%
#collapse
class_values = sorted(papers["subject"].unique())
class_idx = {name: id for id, name in enumerate(class_values)}
paper_idx = {name: idx for idx, name in enumerate(sorted(papers["paper_id"].unique()))}

papers["paper_id"] = papers["paper_id"].apply(lambda name: paper_idx[name])
citations["source"] = citations["source"].apply(lambda name: paper_idx[name])
citations["target"] = citations["target"].apply(lambda name: paper_idx[name])
papers["subject"] = papers["subject"].apply(lambda value: class_idx[value])

# %%
#collapse
plt.figure(figsize=(10, 10))
colors = papers["subject"].tolist()
cora_graph = nx.from_pandas_edgelist(citations.sample(n=800))
subjects = list(papers[papers["paper_id"].isin(list(cora_graph.nodes))]["subject"])
nx.draw_spring(cora_graph, node_size=15, node_color=subjects)

# %% [markdown]
# ### Test vs Train

# %%
#collapse
train_data, test_data = [], []

for _, group_data in papers.groupby("subject"):
    # Select around 50% of the dataset for training.
    random_selection = np.random.rand(len(group_data.index)) <= 0.5
    train_data.append(group_data[random_selection])
    test_data.append(group_data[~random_selection])

train_data = pd.concat(train_data).sample(frac=1)
test_data = pd.concat(test_data).sample(frac=1)

print("Train data shape:", train_data.shape)
print("Test data shape:", test_data.shape)
# Out:
# Train data shape: (515, 8)
# Test data shape: (485, 8)

# %%
#collapse
hidden_units = [32,32]
learning_rate = 0.01
dropout_rate = 0.5
num_epochs = 300
batch_size = 256

# %%
#collapse
feature_names = set(papers.columns) - {"paper_id", "subject"}
num_features = len(feature_names)
num_classes = len(class_idx)

# Create train and test features as a numpy array.
x_train = train_data[feature_names].to_numpy()
x_test = test_data[feature_names].to_numpy()
# Create train and test targets as a numpy array.
y_train = train_data["subject"]
y_test = test_data["subject"]

# %%
#collapse_output
history = run_experiment(baseline_model, x_train, y_train)
# Out:
# Epoch 1/300
# 2/2 [==============================] - 2s 236ms/step - loss: 0.9509 - acc: 0.6087 - val_loss: 0.6017 - val_acc: 0.7308
# Epoch 2/300
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7669 - acc: 0.5881 - val_loss: 0.6505 - val_acc: 0.6026
# Epoch 3/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.7833 - acc: 0.5881 - val_loss: 0.6790 - val_acc: 0.5000
# Epoch 4/300
# 2/2 [==============================] - 0s 36ms/step - loss: 0.7494 - acc: 0.5744 - val_loss: 0.6701 - val_acc: 0.5897
# Epoch 5/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.7438 - acc: 0.5492 - val_loss: 0.6455 - val_acc: 0.7308
# Epoch 6/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.7542 - acc: 0.5973 - val_loss: 0.6331 - val_acc: 0.6923
# Epoch 7/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.7096 - acc: 0.5812 - val_loss: 0.6301 - val_acc: 0.7179
# Epoch 8/300
# 2/2 [==============================] - 0s 50ms/step - loss: 0.7083 - acc: 0.5721 - val_loss: 0.6343 - val_acc: 0.7436
# Epoch 9/300
# 2/2 [==============================] - 0s 46ms/step - loss: 0.7180 - acc: 0.5744 - val_loss: 0.6371 - val_acc: 0.7436
# Epoch 10/300
# 2/2 [==============================] - 0s 53ms/step - loss: 0.6727 - acc: 0.5881 - val_loss: 0.6414 - val_acc: 0.7564
# Epoch 11/300
# 2/2 [==============================] - 0s 45ms/step - loss: 0.6831 - acc: 0.6064 - val_loss: 0.6462 - val_acc: 0.7436
# Epoch 12/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6696 - acc: 0.5904 - val_loss: 0.6496 - val_acc: 0.7436
# Epoch 13/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6590 - acc: 0.6247 - val_loss: 0.6521 - val_acc: 0.6795
# Epoch 14/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6660 - acc: 0.6041 - val_loss: 0.6511 - val_acc: 0.7051
# Epoch 15/300
# 2/2 [==============================] - 0s 39ms/step - loss: 0.7178 - acc: 0.5538 - val_loss: 0.6483 - val_acc: 0.7821
# Epoch 16/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6520 - acc: 0.6453 - val_loss: 0.6439 - val_acc: 0.7308
# Epoch 17/300
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6621 - acc: 0.5904 - val_loss: 0.6403 - val_acc: 0.7308
# Epoch 18/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6753 - acc: 0.5973 - val_loss: 0.6403 - val_acc: 0.6795
# Epoch 19/300
# 2/2 [==============================] - 0s 45ms/step - loss: 0.6700 - acc: 0.5881 - val_loss: 0.6400 - val_acc: 0.6667
# Epoch 20/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6731 - acc: 0.6133 - val_loss: 0.6402 - val_acc: 0.6410
# Epoch 21/300
# 2/2 [==============================] - 0s 48ms/step - loss: 0.6717 - acc: 0.5904 - val_loss: 0.6414 - val_acc: 0.6410
# Epoch 22/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6676 - acc: 0.5881 - val_loss: 0.6418 - val_acc: 0.6923
# Epoch 23/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6478 - acc: 0.6293 - val_loss: 0.6406 - val_acc: 0.7308
# Epoch 24/300
# 2/2 [==============================] - 0s 49ms/step - loss: 0.6684 - acc: 0.5950 - val_loss: 0.6399 - val_acc: 0.7308
# Epoch 25/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.
300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6455 - acc: 0.6407 - val_loss: 0.5974 - val_acc: 0.7308
# Epoch 59/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.6456 - acc: 0.6430 - val_loss: 0.6002 - val_acc: 0.7308
# Epoch 60/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6505 - acc: 0.6224 - val_loss: 0.6012 - val_acc: 0.7308
# Epoch 61/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6364 - acc: 0.6293 - val_loss: 0.5997 - val_acc: 0.7436
# Epoch 62/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6444 - acc: 0.6087 - val_loss: 0.5960 - val_acc: 0.7436
# Epoch 63/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6589 - acc: 0.6133 - val_loss: 0.5961 - val_acc: 0.7436
# Epoch 64/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6513 - acc: 0.6247 - val_loss: 0.5973 - val_acc: 0.7436
# Epoch 65/300
# 2/2 [==============================] - 0s 51ms/step - loss: 0.6724 - acc: 0.6087 - val_loss: 0.6043 - val_acc: 0.7436

# %%
display_learning_curves(history)

# %%
#collapse
_, test_accuracy = baseline_model.evaluate(x=x_test, y=y_test, verbose=0)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 67.22%

# %% [markdown]
# #### p=0.4 Test accuracy: 71.18%

# %% [markdown]
# ### baseline 모델 예측

# %%
#collapse
new_instances = generate_random_instances(num_classes)
logits = baseline_model.predict(new_instances)
probabilities = keras.activations.softmax(tf.convert_to_tensor(logits)).numpy()
display_class_probabilities(probabilities)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f573c0e2160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Instance 1:
# - Deep learning: 48.52%
# - Reinforcement learning: 51.48%
# Instance 2:
# - Deep learning: 50.57%
# - Reinforcement learning: 49.43%

# %%
#collapse
# Create an edges array (sparse adjacency matrix) of shape [2, num_edges].
edges = citations[["source", "target"]].to_numpy().T
# Create an edge weights array of ones.
edge_weights = tf.ones(shape=edges.shape[1])
# Create a node features array of shape [num_nodes, num_features].
node_features = tf.cast(
    papers.sort_values("paper_id")[feature_names].to_numpy(), dtype=tf.dtypes.float32
)
# Create graph info tuple with node_features, edges, and edge_weights.
graph_info = (node_features, edges, edge_weights)

print("Edges shape:", edges.shape)
print("Edge weight shape:", edge_weights.shape)
print("Nodes shape:", node_features.shape)
# Out:
# Edges shape: (2, 4000)
# Edge weight shape: (4000,)
# Nodes shape: (1000, 6)

# %%
#collapse
gnn_model = GNNNodeClassifier(
    graph_info=graph_info,
    num_classes=num_classes,
    hidden_units=hidden_units,
    dropout_rate=dropout_rate,
    name="gnn_model",
)

print("GNN output shape:", gnn_model([1, 10, 100]))

gnn_model.summary()
# Out:
# GNN output shape: tf.Tensor(
# [[ 0.2185007  -0.02331643]
#  [ 0.05068286 -0.08932631]
#  [ 0.14479871 -0.03247471]], shape=(3, 2), dtype=float32)
# Model: "gnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  preprocess (Sequential)     (1000, 32)                1432
#
#  graph_conv1 (GraphConvLayer  multiple                 5888
#  )
#
#  graph_conv2 (GraphConvLayer  multiple                 5888
#  )
#
#  postprocess (Sequential)    (1000, 32)                2368
#
#  logits (Dense)              multiple                  66
#
# =================================================================
# Total params: 15,642
# Trainable params: 14,798
# Non-trainable params: 844
# _________________________________________________________________

# %%
#collapse_Output
x_train = train_data.paper_id.to_numpy()
history = run_experiment(gnn_model, x_train, y_train)
# Out:
# Epoch 1/300
# 2/2 [==============================] - 2s 341ms/step - loss: 0.8990 - acc: 0.4714 - val_loss: 0.6718 - val_acc: 0.6410
# Epoch 2/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.8387 - acc: 0.5103 - val_loss: 0.6789 - val_acc: 0.7308
# Epoch 3/300
# 2/2 [==============================] - 0s 76ms/step - loss: 0.7771 - acc: 0.5263 - val_loss: 0.6787 - val_acc: 0.7308
# Epoch 4/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.7446 - acc: 0.5332 - val_loss: 0.6749 - val_acc: 0.7564
# Epoch 5/300
# 2/2 [==============================] - 0s 73ms/step - loss: 0.7292 - acc: 0.5400 - val_loss: 0.6668 - val_acc: 0.7564
# Epoch 6/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.7470 - acc: 0.5446 - val_loss: 0.6607 - val_acc: 0.7564
# Epoch 7/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.7151 - acc: 0.5240 - val_loss: 0.6584 - val_acc: 0.7564
# Epoch 8/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.7190 - acc: 0.5217 - val_loss: 0.6583 - val_acc: 0.7564
# Epoch 9/300
# 2/2 [==============================] - 0s 95ms/step - loss: 0.7026 - acc: 0.5149 - val_loss: 0.6577 - val_acc: 0.7821
# Epoch 10/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.7170 - acc: 0.5126 - val_loss: 0.6562 - val_acc: 0.7692
# Epoch 11/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.6963 - acc: 0.5332 - val_loss: 0.6552 - val_acc: 0.7436
# Epoch 12/300
# 2/2 [==============================] - 0s 81ms/step - loss: 0.6977 - acc: 0.5263 - val_loss: 0.6545 - val_acc: 0.7692
# Epoch 13/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.6714 - acc: 0.5927 - val_loss: 0.6539 - val_acc: 0.7692
# Epoch 14/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.6769 - acc: 0.5698 - val_loss: 0.6530 - val_acc: 0.7821
# Epoch 15/300
# 2/2 [==============================] - 0s 80ms/step - loss: 0.6869 - acc: 0.5240 - val_loss: 0.6527 - val_acc: 0.7179
# Epoch 16/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.
300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.6658 - acc: 0.6087 - val_loss: 0.5845 - val_acc: 0.7436
# Epoch 49/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.6698 - acc: 0.5973 - val_loss: 0.5903 - val_acc: 0.7436
# Epoch 50/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.6401 - acc: 0.6453 - val_loss: 0.5956 - val_acc: 0.7436
# Epoch 51/300
# 2/2 [==============================] - 0s 86ms/step - loss: 0.6550 - acc: 0.6224 - val_loss: 0.5980 - val_acc: 0.7436
# Epoch 52/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.6507 - acc: 0.6407 - val_loss: 0.5967 - val_acc: 0.7436
# Epoch 53/300
# 2/2 [==============================] - 0s 85ms/step - loss: 0.6807 - acc: 0.5950 - val_loss: 0.6025 - val_acc: 0.7308
# Epoch 54/300
# 2/2 [==============================] - 0s 83ms/step - loss: 0.6650 - acc: 0.6110 - val_loss: 0.6074 - val_acc: 0.7308
# Epoch 55/300
# 2/2 [==============================] - 0s 84ms/step - loss: 0.6639 - acc: 0.6224 - val_loss: 0.6105 - val_acc: 0.7308
# Epoch 56/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.6519 - acc: 0.6270 - val_loss: 0.6071 - val_acc: 0.7308
# Epoch 57/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.6615 - acc: 0.6110 - val_loss: 0.5983 - val_acc: 0.7436
# Epoch 58/300
# 2/2 [==============================] - 0s 77ms/step - loss: 0.6498 - acc: 0.6224 - val_loss: 0.5868 - val_acc: 0.7692
# Epoch 59/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.6425 - acc: 0.6270 - val_loss: 0.5732 - val_acc: 0.7821

# %%
display_learning_curves(history)

# %%
#collapse
x_test = test_data.paper_id.to_numpy()
_, test_accuracy = gnn_model.evaluate(x=x_test, y=y_test, verbose=0)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 67.42%

# %% [markdown]
# #### p=0.4 Test accuracy: 67.45%

# %%
#collapse
# First we add the N new_instances as nodes to the graph
# by appending the new_instance to node_features.
num_nodes = node_features.shape[0]
new_node_features = np.concatenate([node_features, new_instances])
# Second we add the M edges (citations) from each new node to a set
# of existing nodes in a particular subject
new_node_indices = [i + num_nodes for i in range(num_classes)]
new_citations = []
for subject_idx, group in papers.groupby("subject"):
    subject_papers = list(group.paper_id)
    # Select random x papers specific subject.
    selected_paper_indices1 = np.random.choice(subject_papers, 5)
    # Select random y papers from any subject (where y < x).
    selected_paper_indices2 = np.random.choice(list(papers.paper_id), 2)
    # Merge the selected paper indices.
    selected_paper_indices = np.concatenate(
        [selected_paper_indices1, selected_paper_indices2], axis=0
    )
    # Create edges between a citing paper idx and the selected cited papers.
    citing_paper_indx = new_node_indices[subject_idx]
    for cited_paper_idx in selected_paper_indices:
        new_citations.append([citing_paper_indx, cited_paper_idx])

new_citations = np.array(new_citations).T
new_edges = np.concatenate([edges, new_citations], axis=1)

# %%
#collapse
print("Original node_features shape:", gnn_model.node_features.shape)
print("Original edges shape:", gnn_model.edges.shape)
gnn_model.node_features = new_node_features
gnn_model.edges = new_edges
gnn_model.edge_weights = tf.ones(shape=new_edges.shape[1])
print("New node_features shape:", gnn_model.node_features.shape)
print("New edges shape:", gnn_model.edges.shape)

logits = gnn_model.predict(tf.convert_to_tensor(new_node_indices))
probabilities = keras.activations.softmax(tf.convert_to_tensor(logits)).numpy()
display_class_probabilities(probabilities)
# Out:
# Original node_features shape: (1000, 6)
# Original edges shape: (2, 4000)
# New node_features shape: (1002, 6)
# New edges shape: (2, 4014)
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f56e4667940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Instance 1:
# - Deep learning: 49.85%
# - Reinforcement learning: 50.15%
# Instance 2:
# - Deep learning: 51.57%
# - Reinforcement learning: 48.43%

# %% [markdown]
# ## p=0.5

# %% [markdown]
# ### 데이터 구성

# %%
p=0.5

# %%
papers =pd.concat([pd.concat([pd.DataFrame(np.random.choice(2, 1500, p=[p,1-p]).reshape(500,3),columns=['X1','X2','X3']),
           pd.DataFrame(np.random.choice(2, 1500, p=[1-p,p]).reshape(500,3),columns=['X4','X5','X6']),
                             pd.DataFrame(np.array([['Deep learning']*500]).reshape(500,1),columns=['subject'])],axis=1),
            pd.concat([ pd.DataFrame(np.random.choice(2, 1500, p=[1-p,p]).reshape(500,3),columns=['X1','X2','X3']),
              pd.DataFrame(np.random.choice(2, 1500, p=[p,1-p]).reshape(500,3),columns=['X4','X5','X6']),
                      pd.DataFrame(np.array([['Reinforcement learning']*500]).reshape(500,1),columns=['subject'])],axis=1)],axis=0,ignore_index=True).reset_index().rename(columns={'index':'paper_id'})
papers['paper_id'] = papers['paper_id']+1

# %%
# 나머지 1250 행 reinforcement learning 행 500~1000를 target, source에 임의 부여
citations =  pd.concat([pd.DataFrame(np.array([np.random.choice(range(1,501),size=(2000,1)),np.random.choice(range(1,501),size=(2000,1))]).reshape(2000,2)),
                          pd.DataFrame(np.array([np.random.choice(range(501,1001),size=(2000,1)),np.random.choice(range(501,1001),size=(2000,1))]).reshape(2000,2))],ignore_index=True).rename(columns={0:'target',1:'source'})

# %% [markdown]
# ### 그래프 표현

# %%
#collapse
class_values = sorted(papers["subject"].unique())
class_idx = {name: id for id, name in enumerate(class_values)}
paper_idx = {name: idx for idx, name in enumerate(sorted(papers["paper_id"].unique()))}

papers["paper_id"] = papers["paper_id"].apply(lambda name: paper_idx[name])
citations["source"] = citations["source"].apply(lambda name: paper_idx[name])
citations["target"] = citations["target"].apply(lambda name: paper_idx[name])
papers["subject"] = papers["subject"].apply(lambda value: class_idx[value])

# %%
#collapse
plt.figure(figsize=(10, 10))
colors = papers["subject"].tolist()
cora_graph = nx.from_pandas_edgelist(citations.sample(n=800))
subjects = list(papers[papers["paper_id"].isin(list(cora_graph.nodes))]["subject"])
nx.draw_spring(cora_graph, node_size=15, node_color=subjects)

# %% [markdown]
# ### Test vs Train

# %%
#collapse
train_data, test_data = [], []

for _, group_data in papers.groupby("subject"):
    # Select around 50% of the dataset for training.
    random_selection = np.random.rand(len(group_data.index)) <= 0.5
    train_data.append(group_data[random_selection])
    test_data.append(group_data[~random_selection])

train_data = pd.concat(train_data).sample(frac=1)
test_data = pd.concat(test_data).sample(frac=1)

print("Train data shape:", train_data.shape)
print("Test data shape:", test_data.shape)
# Out:
# Train data shape: (496, 8)
# Test data shape: (504, 8)

# %%
#collapse
hidden_units = [32,32]
learning_rate = 0.01
dropout_rate = 0.5
num_epochs = 300
batch_size = 256

# %%
#collapse
feature_names = set(papers.columns) - {"paper_id", "subject"}
num_features = len(feature_names)
num_classes = len(class_idx)

# Create train and test features as a numpy array.
x_train = train_data[feature_names].to_numpy()
x_test = test_data[feature_names].to_numpy()
# Create train and test targets as a numpy array.
y_train = train_data["subject"]
y_test = test_data["subject"]

# %%
#collapse_output
history = run_experiment(baseline_model, x_train, y_train)
# Out:
# Epoch 1/300
# 2/2 [==============================] - 2s 240ms/step - loss: 0.8131 - acc: 0.4679 - val_loss: 0.7045 - val_acc: 0.4133
# Epoch 2/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.7206 - acc: 0.5083 - val_loss: 0.7075 - val_acc: 0.4267
# Epoch 3/300
# 2/2 [==============================] - 0s 34ms/step - loss: 0.7302 - acc: 0.4869 - val_loss: 0.6979 - val_acc: 0.4667
# Epoch 4/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.7172 - acc: 0.4917 - val_loss: 0.6918 - val_acc: 0.4800
# Epoch 5/300
# 2/2 [==============================] - 0s 45ms/step - loss: 0.6978 - acc: 0.5297 - val_loss: 0.6892 - val_acc: 0.5467
# Epoch 6/300
# 2/2 [==============================] - 0s 45ms/step - loss: 0.7015 - acc: 0.5321 - val_loss: 0.6879 - val_acc: 0.6267
# Epoch 7/300
# 2/2 [==============================] - 0s 41ms/step - loss: 0.7156 - acc: 0.4893 - val_loss: 0.6859 - val_acc: 0.6000
# Epoch 8/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.7111 - acc: 0.4941 - val_loss: 0.6860 - val_acc: 0.5733
# Epoch 9/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.7069 - acc: 0.5511 - val_loss: 0.6891 - val_acc: 0.5467
# Epoch 10/300
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6956 - acc: 0.5344 - val_loss: 0.6930 - val_acc: 0.5200
# Epoch 11/300
# 2/2 [==============================] - 0s 39ms/step - loss: 0.7028 - acc: 0.5012 - val_loss: 0.6956 - val_acc: 0.4800
# Epoch 12/300
# 2/2 [==============================] - 0s 39ms/step - loss: 0.7055 - acc: 0.5083 - val_loss: 0.6964 - val_acc: 0.4667
# Epoch 13/300
# 2/2 [==============================] - 0s 40ms/step - loss: 0.6984 - acc: 0.4917 - val_loss: 0.6961 - val_acc: 0.5333
# Epoch 14/300
# 2/2 [==============================] - 0s 45ms/step - loss: 0.7083 - acc: 0.4917 - val_loss: 0.6958 - val_acc: 0.5200
# Epoch 15/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6950 - acc: 0.5439 - val_loss: 0.6953 - val_acc: 0.4933
# Epoch 16/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6976 - acc: 0.5463 - val_loss: 0.6943 - val_acc: 0.5200
# Epoch 17/300
# 2/2 [==============================] - 0s 38ms/step - loss: 0.
# 2/2 [==============================] - 0s 36ms/step - loss: 0.7016 - acc: 0.5249 - val_loss: 0.7161 - val_acc: 0.3867
# Epoch 49/300
# 2/2 [==============================] - 0s 35ms/step - loss: 0.7023 - acc: 0.5344 - val_loss: 0.7127 - val_acc: 0.3867
# Epoch 50/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.7045 - acc: 0.5297 - val_loss: 0.7099 - val_acc: 0.3867
# Epoch 51/300
# 2/2 [==============================] - 0s 43ms/step - loss: 0.6968 - acc: 0.5368 - val_loss: 0.7053 - val_acc: 0.3867
# Epoch 52/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6977 - acc: 0.5154 - val_loss: 0.6988 - val_acc: 0.4533
# Epoch 53/300
# 2/2 [==============================] - 0s 44ms/step - loss: 0.6977 - acc: 0.5107 - val_loss: 0.6939 - val_acc: 0.4800
# Epoch 54/300
# 2/2 [==============================] - 0s 49ms/step - loss: 0.7023 - acc: 0.5107 - val_loss: 0.6924 - val_acc: 0.4933
# Epoch 55/300
# 2/2 [==============================] - 0s 42ms/step - loss: 0.6914 - acc: 0.5226 - val_loss: 0.6952 - val_acc: 0.4800
# Epoch 56/300
# 2/2 [==============================] - 0s 56ms/step - loss: 0.6890 - acc: 0.5558 - val_loss: 0.6978 - val_acc: 0.4667

# %%
display_learning_curves(history)

# %%
#collapse
_, test_accuracy = baseline_model.evaluate(x=x_test, y=y_test, verbose=0)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 51.39%

# %% [markdown]
# #### p=0.5 Test accuracy: 49.33%

# %% [markdown]
# ### baseline 모델 예측

# %%
#collapse
new_instances = generate_random_instances(num_classes)
logits = baseline_model.predict(new_instances)
probabilities = keras.activations.softmax(tf.convert_to_tensor(logits)).numpy()
display_class_probabilities(probabilities)
# Out:
# Instance 1:
# - Deep learning: 50.93%
# - Reinforcement learning: 49.07%
# Instance 2:
# - Deep learning: 50.63%
# - Reinforcement learning: 49.37%

# %%
#collapse
# Create an edges array (sparse adjacency matrix) of shape [2, num_edges].
edges = citations[["source", "target"]].to_numpy().T
# Create an edge weights array of ones.
edge_weights = tf.ones(shape=edges.shape[1])
# Create a node features array of shape [num_nodes, num_features].
node_features = tf.cast(
    papers.sort_values("paper_id")[feature_names].to_numpy(), dtype=tf.dtypes.float32
)
# Create graph info tuple with node_features, edges, and edge_weights.
graph_info = (node_features, edges, edge_weights)

print("Edges shape:", edges.shape)
print("Edge weight shape:", edge_weights.shape)
print("Nodes shape:", node_features.shape)
# Out:
# Edges shape: (2, 4000)
# Edge weight shape: (4000,)
# Nodes shape: (1000, 6)

# %%
#collapse
gnn_model = GNNNodeClassifier(
    graph_info=graph_info,
    num_classes=num_classes,
    hidden_units=hidden_units,
    dropout_rate=dropout_rate,
    name="gnn_model",
)

print("GNN output shape:", gnn_model([1, 10, 100]))

gnn_model.summary()
# Out:
# GNN output shape: tf.Tensor(
# [[-0.05169908 -0.06133673]
#  [-0.03542037 -0.01879554]
#  [ 0.04836449 -0.04186281]], shape=(3, 2), dtype=float32)
# Model: "gnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  preprocess (Sequential)     (1000, 32)                1432
#
#  graph_conv1 (GraphConvLayer  multiple                 5888
#  )
#
#  graph_conv2 (GraphConvLayer  multiple                 5888
#  )
#
#  postprocess (Sequential)    (1000, 32)                2368
#
#  logits (Dense)              multiple                  66
#
# =================================================================
# Total params: 15,642
# Trainable params: 14,798
# Non-trainable params: 844
# _________________________________________________________________

# %%
#collapse_Output
x_train = train_data.paper_id.to_numpy()
history = run_experiment(gnn_model, x_train, y_train)
# Out:
# Epoch 1/300
# 2/2 [==============================] - 2s 331ms/step - loss: 0.9717 - acc: 0.5582 - val_loss: 0.7027 - val_acc: 0.4267
# Epoch 2/300
# 2/2 [==============================] - 0s 69ms/step - loss: 0.
# 2/2 [==============================] - 0s 74ms/step - loss: 0.6943 - acc: 0.5178 - val_loss: 0.6970 - val_acc: 0.4400
# Epoch 62/300
# 2/2 [==============================] - 0s 79ms/step - loss: 0.6911 - acc: 0.5321 - val_loss: 0.6959 - val_acc: 0.4267
# Epoch 63/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.6958 - acc: 0.5154 - val_loss: 0.6952 - val_acc: 0.4400
# Epoch 64/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.6941 - acc: 0.5202 - val_loss: 0.6954 - val_acc: 0.4400
# Epoch 65/300
# 2/2 [==============================] - 0s 87ms/step - loss: 0.6944 - acc: 0.5036 - val_loss: 0.6951 - val_acc: 0.4533
# Epoch 66/300
# 2/2 [==============================] - 0s 82ms/step - loss: 0.6895 - acc: 0.5463 - val_loss: 0.6951 - val_acc: 0.4667
# Epoch 67/300
# 2/2 [==============================] - 0s 94ms/step - loss: 0.6923 - acc: 0.5036 - val_loss: 0.6953 - val_acc: 0.4667

# %%
display_learning_curves(history)

# %%
#collapse
x_test = test_data.paper_id.to_numpy()
_, test_accuracy = gnn_model.evaluate(x=x_test, y=y_test, verbose=0)
print(f"Test accuracy: {round(test_accuracy * 100, 2)}%")
# Out:
# Test accuracy: 52.38%

# %% [markdown]
# #### p=0.5 Test accuracy: 48.76%

# %%
#collapse
# First we add the N new_instances as nodes to the graph
# by appending the new_instance to node_features.
num_nodes = node_features.shape[0]
new_node_features = np.concatenate([node_features, new_instances])
# Second we add the M edges (citations) from each new node to a set
# of existing nodes in a particular subject
new_node_indices = [i + num_nodes for i in range(num_classes)]
new_citations = []
for subject_idx, group in papers.groupby("subject"):
    subject_papers = list(group.paper_id)
    # Select random x papers specific subject.
    selected_paper_indices1 = np.random.choice(subject_papers, 5)
    # Select random y papers from any subject (where y < x).
    selected_paper_indices2 = np.random.choice(list(papers.paper_id), 2)
    # Merge the selected paper indices.
    selected_paper_indices = np.concatenate(
        [selected_paper_indices1, selected_paper_indices2], axis=0
    )
    # Create edges between a citing paper idx and the selected cited papers.
    citing_paper_indx = new_node_indices[subject_idx]
    for cited_paper_idx in selected_paper_indices:
        new_citations.append([citing_paper_indx, cited_paper_idx])

new_citations = np.array(new_citations).T
new_edges = np.concatenate([edges, new_citations], axis=1)

# %%
#collapse
print("Original node_features shape:", gnn_model.node_features.shape)
print("Original edges shape:", gnn_model.edges.shape)
gnn_model.node_features = new_node_features
gnn_model.edges = new_edges
gnn_model.edge_weights = tf.ones(shape=new_edges.shape[1])
print("New node_features shape:", gnn_model.node_features.shape)
print("New edges shape:", gnn_model.edges.shape)

logits = gnn_model.predict(tf.convert_to_tensor(new_node_indices))
probabilities = keras.activations.softmax(tf.convert_to_tensor(logits)).numpy()
display_class_probabilities(probabilities)
# Out:
# Original node_features shape: (1000, 6)
# Original edges shape: (2, 4000)
# New node_features shape: (1002, 6)
# New edges shape: (2, 4014)
# Instance 1:
# - Deep learning: 50.16%
# - Reinforcement learning: 49.84%
# Instance 2:
# - Deep learning: 49.51%
# - Reinforcement learning: 50.49%
